# %%
pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (1.2.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import app
from google_play_scraper import Sort, reviews_all
import pandas as pd
import numpy as np

# %%
ulasan_aplikasi = reviews_all(
    'com.linkdokter.halodoc.android', #ID aplikasi
    lang='id', #defaults to ‘en’
    country='id', #defaults to ‘us’
    sort=Sort.NEWEST, #defaults to Sort.NEWEST_RELEVANT
)

# scrapreview= reviews_all(
# ‘com.siloam.android&hl’, #ID aplikasi
# lang=’id’, # defaults to ‘en’
# country=’id’, # defaults to ‘us’
# sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
# filter_score_with=1 # defaults to None (means all score)
# )

# %%
data=pd.DataFrame(np.array(ulasan_aplikasi),columns=['review'])
data = data.join(pd.DataFrame(data.pop('review').tolist()))
data.head()
# Out:
#                                reviewId                userName  \
# 0  d54f520d-5edf-4e8a-8954-73493aa64b21     Madyla N Firmansyah
# 1  67efcfb1-f80c-40ef-bd2b-3fc5e20e98aa         Munadif (Nadif)
# 2  74a042e3-1d4f-4d39-9d60-215a1050aebb       Indra Ahmad Riadi
# 3  d873bbeb-0131-4151-bb57-f6d2a3b80474  Hanny Nur Fityaningsih
# 4  94072ef1-a315-44be-9243-a68441170585            Enur Rosmaya
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a/AAcHTt...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a/AAcHTt...
#
#                                              content  score  thumbsUpCount  \
# 0  Layanan pengiriman buruk. Konsultasinya okey t...      1             16
# 1  Kalo ngga niat promo mending ngga usah adain p...      1              9
# 2  Solusi mudah dalam genggaman untuk konsultasi ...      5              5
# 3  Sangat bermanfaat untuk kita konsultasi.. Dokt...      5              7
# 4  Bagus, praktis. Kendalanya pembayaran debit di...      4              3
#
#   reviewCreatedVersion                  at  \
# 0               18.300 2023-08-20 18:13:47
# 1               18.501 2023-08-23 17:11:50
# 2               18.300 2023-08-17 09:09:04
# 3               18.300 2023-08-15 16:59:16
# 4               17.303 2023-08-13 15:57:28
#
#                                         replyContent           repliedAt  \
# 0  Hai Madyla N Firmansyah! Mohon maaf atas ketid... 2023-08-20 18:12:52
# 1  Hai Munadif (Nadif)! Mohon maaf atas ketidakny... 2023-08-23 18:00:05
# 2  Hai Indra Ahmad Riadi! Terima kasih sudah meng... 2023-08-17 10:09:19
# 3  Hai Hanny Nur Fityaningsih! Terima kasih sudah... 2023-08-15 17:05:13
# 4  Hai Enur Rosmaya! Mohon maaf atas ketidaknyama... 2023-08-13 15:59:55
#
#   appVersion
# 0     18.300
# 1     18.501
# 2     18.300
# 3     18.300
# 4     17.303

# %%
len(data)
# Out:
# 91370

# %%
data=data[['content']]
data.head()
# Out:
#                                              content
# 0  Layanan pengiriman buruk. Konsultasinya okey t...
# 1  Kalo ngga niat promo mending ngga usah adain p...
# 2  Solusi mudah dalam genggaman untuk konsultasi ...
# 3  Sangat bermanfaat untuk kita konsultasi.. Dokt...
# 4  Bagus, praktis. Kendalanya pembayaran debit di...

# %%
data = data.rename(columns={'content':'ulasan'})
data.head()
# Out:
#                                               ulasan
# 0  Layanan pengiriman buruk. Konsultasinya okey t...
# 1  Kalo ngga niat promo mending ngga usah adain p...
# 2  Solusi mudah dalam genggaman untuk konsultasi ...
# 3  Sangat bermanfaat untuk kita konsultasi.. Dokt...
# 4  Bagus, praktis. Kendalanya pembayaran debit di...

# %%
data.to_csv("ulasan halodoc.csv",index=False, encoding='utf-8')

# %%
# dataMtix=pd.read_csv('C:/Users/ASUS/ulasan MTIX raw.csv')
dataMtix=pd.read_csv('C:/Users/Achmad Faturohman/Data Scrape Google Play/ulasan halodoc.csv')
dataMtix.head()
# Out:
#                                               ulasan
# 0  Layanan pengiriman buruk. Konsultasinya okey t...
# 1  Kalo ngga niat promo mending ngga usah adain p...
# 2  Solusi mudah dalam genggaman untuk konsultasi ...
# 3  Sangat bermanfaat untuk kita konsultasi.. Dokt...
# 4  Bagus, praktis. Kendalanya pembayaran debit di...

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from nltk) (2023.8.8)
# Requirement already satisfied: tqdm in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from nltk) (4.66.1)
# Requirement already satisfied: colorama in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Sastrawi
# Out:
# Requirement already satisfied: Sastrawi in c:\users\achmad faturohman\appdata\local\programs\python\python311\lib\site-packages (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import string 
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.tokenize import sent_tokenize, word_tokenize
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Achmad
# [nltk_data]     Faturohman\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data = pd.read_csv('ulasan halodoc.csv')

# %%
print(data.dtypes)
# Out:
# ulasan    object
# dtype: object

# %%
data["ulasan"] = data["ulasan"].astype(str)
data["ulasan"] = [x.replace(':',' ') for x in data["ulasan"]]

# %%
#case folding
data['ulasan'] = data['ulasan'].str.lower()
data
# Out:
#                                                   ulasan
# 0      layanan pengiriman buruk. konsultasinya okey t...
# 1      kalo ngga niat promo mending ngga usah adain p...
# 2      solusi mudah dalam genggaman untuk konsultasi ...
# 3      sangat bermanfaat untuk kita konsultasi.. dokt...
# 4      bagus, praktis. kendalanya pembayaran debit di...
# ...                                                  ...
# 91365                                                sif
# 91366                                               good
# 91367                                               okey
# 91368                                                jal
# 91369                                              bagus
#
# [91370 rows x 1 columns]

# %%
#data cleaning 

def clean(text):
    # tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    return text

data['ulasan'] = data['ulasan'].apply(clean)

# %%
#remove number
def clean_num(text):
    return  re.sub(r"\d+", "", text)

data['ulasan'] = data['ulasan'].apply(clean_num)

# %%
#remove punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

data['ulasan'] = data['ulasan'].apply(remove_punctuation)

# %%
#remove whitespace
def remove_whitespace_LT(text):
    return text.strip()

data['ulasan'] = data['ulasan'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

data['ulasan'] = data['ulasan'].apply(remove_whitespace_multiple)

# %%
# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

data['ulasan'] = data['ulasan'].apply(remove_singl_char)

# %%
# NLTK word tokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

data['tokenize'] = data['ulasan'].apply(word_tokenize_wrapper)

data
# Out:
#                                                   ulasan  \
# 0      layanan pengiriman buruk konsultasinya okey tp...
# 1      kalo ngga niat promo mending ngga usah adain p...
# 2      solusi mudah dalam genggaman untuk konsultasi ...
# 3      sangat bermanfaat untuk kita konsultasi dokter...
# 4      bagus praktis kendalanya pembayaran debit dito...
# ...                                                  ...
# 91365                                                sif
# 91366                                               good
# 91367                                               okey
# 91368                                                jal
# 91369                                              bagus
#
#                                                 tokenize
# 0      [layanan, pengiriman, buruk, konsultasinya, ok...
# 1      [kalo, ngga, niat, promo, mending, ngga, usah,...
# 2      [solusi, mudah, dalam, genggaman, untuk, konsu...
# 3      [sangat, bermanfaat, untuk, kita, konsultasi, ...
# 4      [bagus, praktis, kendalanya, pembayaran, debit...
# ...                                                  ...
# 91365                                              [sif]
# 91366                                             [good]
# 91367                                             [okey]
# 91368                                              [jal]
# 91369                                            [bagus]
#
# [91370 rows x 2 columns]

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')
# stopword tambahan
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah','bak','haii'])
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Achmad
# [nltk_data]     Faturohman\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#stopword merupakan algoritma untuk menghapuskan kata kata yang tidak perlu 
#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
data['stopw'] = data['tokenize'].apply(stopwords_removal) 


data
# Out:
#                                                   ulasan  \
# 0      layanan pengiriman buruk konsultasinya okey tp...
# 1      kalo ngga niat promo mending ngga usah adain p...
# 2      solusi mudah dalam genggaman untuk konsultasi ...
# 3      sangat bermanfaat untuk kita konsultasi dokter...
# 4      bagus praktis kendalanya pembayaran debit dito...
# ...                                                  ...
# 91365                                                sif
# 91366                                               good
# 91367                                               okey
# 91368                                                jal
# 91369                                              bagus
#
#                                                 tokenize  \
# 0      [layanan, pengiriman, buruk, konsultasinya, ok...
# 1      [kalo, ngga, niat, promo, mending, ngga, usah,...
# 2      [solusi, mudah, dalam, genggaman, untuk, konsu...
# 3      [sangat, bermanfaat, untuk, kita, konsultasi, ...
# 4      [bagus, praktis, kendalanya, pembayaran, debit...
# ...                                                  ...
# 91365                                              [sif]
# 91366                                             [good]
# 91367                                             [okey]
# 91368                                              [jal]
# 91369                                            [bagus]
#
#                                                    stopw
# 0      [layanan, pengiriman, buruk, konsultasinya, ok...
# 1      [ngga, niat, promo, mending, ngga, adain, prom...
# 2      [solusi, mudah, genggaman, konsultasi, repot, ...
# 3      [bermanfaat, konsultasi, dokternya, ramah, sab...
# 4      [bagus, praktis, kendalanya, pembayaran, debit...
# ...                                                  ...
# 91365                                              [sif]
# 91366                                             [good]
# 91367                                             [okey]
# 91368                                              [jal]
# 91369                                            [bagus]
#
# [91370 rows x 3 columns]

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data['tokenize']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

# %%
print(len(term_dict))

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
# Out:
# 27567
# 1 : layanan : layan
# 2 : pengiriman : kirim
# 3 : buruk : buruk
# 4 : konsultasinya : konsultasi
# 5 : okey : okey
# 6 : tp : tp
# 7 : pengirimannya : kirim
# 8 : lelet : lelet
# 9 : sekali : sekali
# 10 : pesan : pesan
# 11 : dari : dari
# 12 : jam : jam
# 13 : sampe : sampe
# 14 : sore : sore
# 15 : baru : baru
# 16 : otw : otw
# 17 : harusnya : harus
# 18 : langsung : langsung
# 19 : ada : ada
# 20 : pilihan : pilih
# 21 : apotek : apotek
# 22 : mana : mana
# 23 : yg : yg
# 24 : terdekat : dekat
# 25 : lalu : lalu
# 26 : dihubungkan : hubung
# 27 : dg : dg
# 28 : aplikasi : aplikasi
# 29 : order : order
# 30 : cuma : cuma
# 31 : beli : beli
# 32 : obat : obat
# 33 : nunggunya : nunggunya
# 34 : lama : lama
# 35 : kalo : kalo
# 36 : ngga : ngga
# 37 : niat : niat
# 38 : promo : promo
# 39 : mending : mending
# 40 : usah : usah
# 41 : adain : adain
# 42 : setelah : telah
# 43 : pakai : pakai
# 44 : kode : kode
# 45 : sudah : sudah
# 46 : tiba : tiba
# 47 : cancel : cancel
# 48 : refund : refund
# 49 : juga : juga
# 50 : bisa : bisa
# 51 : login : login
# 52 : parah : parah
# 53 : solusi : solusi
# 54 : mudah : mudah
# 55 : dalam : dalam
# 56 : genggaman : genggam
# 57 : untuk : untuk
# 58 : konsultasi : konsultasi
# 59 : tanpa : tanpa
# 60 : harus : harus
# 61 : repot : repot
# 62 : ke : ke
# 63 : datang : datang
# 64 : rs : rs
# 65 : atau : atau
# 66 : praktik : praktik
# 67 : dokter : dokter
# 68 : umumtinggal : umumtinggal
# 69 : buka : buka
# 70 : halodoc : halodoc
# 71 : jd : jd
# 72 : lbh : lbh
# 73 : dan : dan
# 74 : cepat : cepat
# 75 : sangat : sangat
# 76 : bermanfaat : manfaat
# 77 : kita : kita
# 78 : dokternya : dokter
# 79 : ramah : ramah
# 80 : sabar : sabar
# 81 : detail : detail
# 82 : dlam : dlam
# 83 : menyampaikan : sampai
# 84 : keluhan : keluh
# 85 : pasien : pasien
# 86 : membantu : bantu
# 87 : bagus : bagus
# 88 : praktis : praktis
# 89 : kendalanya : kendala
# 90 : pembayaran : bayar
# 91 : debit : debit
# 92 : ditolak : tolak
# 93 : terus : terus
# 94 : tapi : tapi
# 95 : oke : oke
# 96 : ga : ga
# 97 : apa : apa
# 98 : masih : masih
# 99 : yang : yang
# 100 : lain : lain
# 101 : jadi : jadi
# 102 : masalah : masalah
# 103 : kalau : kalau
# 104 : dapat : dapat
# 105 : kenapa : kenapa
# 106 : jauh : jauh
# 107 : amat : amat
# 108 : ya : ya
# 109 : padahal : padahal
# 110 : di : di
# 111 : sekitar : sekitar
# 112 : banyak : banyak
# 113 : lebih : lebih
# 114 : dekat : dekat
# 115 : saja : saja
# 116 : poin : poin
# 117 : ini : ini
# 118 : diperbaiki : baik
# 119 : saya : saya
# 120 : gak : gak
# 121 : pilih : pilih
# 122 : apotik : apotik
# 123 : malah : malah
# 124 : nya : nya
# 125 : tutup : tutup
# 126 : uda : uda
# 127 : kna : kna
# 128 : asam : asam
# 129 : lambung : lambung
# 130 : tengah : tengah
# 131 : malam : malam
# 132 : drivernya : drivernya
# 133 : cxl : cxl
# 134 : trs : trs
# 135 : gk : gk
# 136 : guna : guna
# 137 : mau : mau
# 138 : pesanan : pesan
# 139 : obatnya : obat
# 140 : nih : nih
# 141 : depelovernya : depelovernya
# 142 : komplen : komplen
# 143 : masa : masa
# 144 : kali : kali
# 145 : konsul : konsul
# 146 : itu : itu
# 147 : satu : satu
# 148 : sukses : sukses
# 149 : semua : semua
# 150 : apaan : apa
# 151 : coba : coba
# 152 : uang : uang
# 153 : belum : belum
# 154 : sekarang : sekarang
# 155 : benar : benar
# 156 : gw : gw
# 157 : bener : bener
# 158 : minta : minta
# 159 : tolong : tolong
# 160 : sama : sama
# 161 : lo : lo
# 162 : depelover : depelover
# 163 : perbaiki : baik
# 164 : sistem : sistem
# 165 : aplikasimu : aplikasi
# 166 : gini : gin
# 167 : kasih : kasih
# 168 : saran : saran
# 169 : jangan : jangan
# 170 : saldo : saldo
# 171 : orang : orang
# 172 : dipotong : potong
# 173 : sebelum : belum
# 174 : konsulterhubung : konsulterhubung
# 175 : nah : nah
# 176 : ketika : ketika
# 177 : berhasil : hasil
# 178 : dgn : dgn
# 179 : dah : dah
# 180 : terpotong : potong
# 181 : bikin : bikin
# 182 : app : app
# 183 : sepanjang : panjang
# 184 : pengalaman : alam
# 185 : menggunakan : guna
# 186 : apalagi : apalagi
# 187 : pas : pas
# 188 : malem : malem
# 189 : butuh : butuh
# 190 : situasi : situasi
# 191 : tdk : tdk
# 192 : memungkinkan : mungkin
# 193 : utk : utk
# 194 : keluar : keluar
# 195 : rumah : rumah
# 196 : responsif : responsif
# 197 : antar : antar
# 198 : sering : sering
# 199 : loading : loading
# 200 : alasan : alas
# 201 : tidak : tidak
# 202 : koneksi : koneksi
# 203 : lancar : lancar
# 204 : jaya : jaya
# 205 : pastikan : pasti
# 206 : wifi : wifi
# 207 : maupun : maupun
# 208 : internet : internet
# 209 : alhasil : alhasil
# 210 : sesi : sesi
# 211 : habis : habis
# 212 : waktunya : waktu
# 213 : konsulbayar : konsulbayar
# 214 : ulang : ulang
# 215 : mengecewakan : kecewa
# 216 : dibayar : bayar
# 217 : dihistori : histori
# 218 : pemesanan : mesan
# 219 : cek : cek
# 220 : tracking : tracking
# 221 : ordernya : order
# 222 : pembatalan : batal
# 223 : dipersulit : sulit
# 224 : dini : dini
# 225 : hari : hari
# 226 : berharap : harap
# 227 : dianterin : dianterin
# 228 : cepet : cepet
# 229 : driver : driver
# 230 : dihubungi : hubung
# 231 : udah : udah
# 232 : nunggu : nunggu
# 233 : menit : menit
# 234 : kabar : kabar
# 235 : harga : harga
# 236 : tertera : tera
# 237 : berbeda : beda
# 238 : karena : karena
# 239 : melakukan : laku
# 240 : pihak : pihak
# 241 : telfon : telfon
# 242 : menginformasikan : informasi
# 243 : perbedaan : beda
# 244 : suruh : suruh
# 245 : bayar : bayar
# 246 : lagi : lagi
# 247 : kekurangannya : kurang
# 248 : komunikasi : komunikasi
# 249 : berbagai : bagai
# 250 : ataupun : atau
# 251 : cs : cs
# 252 : pulsa : pulsa
# 253 : mahal : mahal
# 254 : susah : susah
# 255 : laporan : lapor
# 256 : ongkos : ongkos
# 257 : pelayanannya : layan
# 258 : selama : lama
# 259 : bulan : bulan
# 260 : lewat : lewat
# 261 : kartu : kartu
# 262 : kredit : kredit
# 263 : slalu : slalu
# 264 : menghubungi : hubung
# 265 : bank : bank
# 266 : katanya : kata
# 267 : transaksi : transaksi
# 268 : ecommerce : ecommerce
# 269 : hanya : hanya
# 270 : terima : terima
# 271 : gopay : gopay
# 272 : secepatnya : cepat
# 273 : pengembalian : kembali
# 274 : dana : dana
# 275 : kerja : kerja
# 276 : zaman : zaman
# 277 : skrng : skrng
# 278 : masukin : masukin
# 279 : tarik : tarik
# 280 : seperti : seperti
# 281 : lainya : lai
# 282 : baikkk : baikkk
# 283 : apk : apk
# 284 : mempermudah : mudah
# 285 : gaperlu : gaperlu
# 286 : tatapmuka : tatapmuka
# 287 : via : via
# 288 : online : online
# 289 : aq : aq
# 290 : uninstall : uninstall
# 291 : soalnya : soal
# 292 : waktu : waktu
# 293 : buat : buat
# 294 : janji : janji
# 295 : ternyata : nyata
# 296 : realtime : realtime
# 297 : konfirmasinya : konfirmasi
# 298 : hasil : hasil
# 299 : capede : capede
# 300 : nama : nama
# 301 : pada : pada
# 302 : profil : profil
# 303 : berulang : ulang
# 304 : diverifikasi : verifikasi
# 305 : sehingga : sehingga
# 306 : berani : berani
# 307 : melanjutkan : lanjut
# 308 : proses : proses
# 309 : daftar : daftar
# 310 : karna : karna
# 311 : data : data
# 312 : need : need
# 313 : help : help
# 314 : real : real
# 315 : kl : kl
# 316 : udh : udh
# 317 : benerin : benerin
# 318 : ubah : ubah
# 319 : updated : updated
# 320 : yaa : yaa
# 321 : aneh : aneh
# 322 : chat : chat
# 323 : panjang : panjang
# 324 : lebar : lebar
# 325 : nanya : nanya
# 326 : keluhannya : keluh
# 327 : read : read
# 328 : dikasih : kasih
# 329 : catatan : catat
# 330 : akhiri : akhir
# 331 : sm : sm
# 332 : kan : kan
# 333 : akhirnya : akhir
# 334 : bagi : bagi
# 335 : seseorang : orang
# 336 : menjadi : jadi
# 337 : istri : istri
# 338 : sedang : sedang
# 339 : promil : promil
# 340 : bingung : bingung
# 341 : tau : tau
# 342 : setidaknya : tidak
# 343 : dengan : dengan
# 344 : mengurangi : kurang
# 345 : sedikit : sedikit
# 346 : kekhawatiran : khawatir
# 347 : diri : diri
# 348 : terimakasih : terimakasih
# 349 : dibatalkan : batal
# 350 : sepihak : pihak
# 351 : jelasudah : jelasudah
# 352 : apply : apply
# 353 : pengguna : guna
# 354 : barueh : barueh
# 355 : batal : batal
# 356 : begitu : begitu
# 357 : sajaaplikasi : sajaaplikasi
# 358 : kesehatan : sehat
# 359 : notabene : notabene
# 360 : sampah : sampah
# 361 : doangjangan : doangjangan
# 362 : downloadmending : downloadmending
# 363 : jelas : jelas
# 364 : promonya : promonya
# 365 : web : web
# 366 : eror : eror
# 367 : sibuk : sibuk
# 368 : offline : offline
# 369 : semuanya : semua
# 370 : giliran : gilir
# 371 : selalu : selalu
# 372 : bermasalah : masalah
# 373 : ingin : ingin
# 374 : baik : baik
# 375 : kok : kok
# 376 : awalnya : awal
# 377 : masuk : masuk
# 378 : nyambung : nyambung
# 379 : tolak : tolak
# 380 : dikembalikan : kembali
# 381 : barang : barang
# 382 : sampai : sampai
# 383 : riwayat : riwayat
# 384 : kurirnya : kurir
# 385 : edukasi : edukasi
# 386 : pengantaran : antar
# 387 : kurir : kurir
# 388 : bukti : bukti
# 389 : penerimaan : terima
# 390 : kedepannya : depan
# 391 : video : video
# 392 : call : call
# 393 : agar : agar
# 394 : memuaskan : muas
# 395 : memudahkan : mudah
# 396 : tan : tan
# 397 : aja : aja
# 398 : terkadang : terkadang
# 399 : suka : suka
# 400 : miss : miss
# 401 : kamis : kamis
# 402 : terkonfirmasi : konfirmasi
# 403 : tertulis : tulis
# 404 : akan : akan
# 405 : dihari : hari
# 406 : minggu : minggu
# 407 : eh : eh
# 408 : sabtunya : sabtu
# 409 : batalkan : batal
# 410 : kecewa : kecewa
# 411 : banget : banget
# 412 : memang : memang
# 413 : sih : sih
# 414 : rasa : rasa
# 415 : tetap : tetap
# 416 : install : install
# 417 : mintain : mintain
# 418 : sales : sales
# 419 : eveht : eveht
# 420 : kampus : kampus
# 421 : dapet : dapet
# 422 : produk : produk
# 423 : rb : rb
# 424 : kemudian : kemudian
# 425 : wkwk : wkwk
# 426 : temen : temen
# 427 : cancek : cancek
# 428 : bukan : bukan
# 429 : duitnya : duit
# 430 : cara : cara
# 431 : nyari : nyari
# 432 : aplikasinya : aplikasi
# 433 : kocak : kocak
# 434 : melalui : lalu
# 435 : top : top
# 436 : up : up
# 437 : melalu : lalu
# 438 : banking : banking
# 439 : menyulitkan : sulit
# 440 : bertransaksi : transaksi
# 441 : developer : developer
# 442 : tingkatkan : tingkat
# 443 : fitur : fitur
# 444 : kualitas : kualitas
# 445 : pelayanan : layan
# 446 : pagi : pagi
# 447 : berpikir : pikir
# 448 : menerima : terima
# 449 : resep : resep
# 450 : operasional : operasional
# 451 : kemajuan : maju
# 452 : respon : respon
# 453 : diaplikasi : aplikasi
# 454 : status : status
# 455 : ditugaskan : tugas
# 456 : live : live
# 457 : alias : alias
# 458 : oleh : oleh
# 459 : info : info
# 460 : hubungi : hubung
# 461 : kemana : mana
# 462 : alhamdulillah : alhamdulillah
# 463 : disaat : saat
# 464 : urgent : urgent
# 465 : pernah : pernah
# 466 : angkat : angkat
# 467 : kembalikan : kembali
# 468 : halo : halo
# 469 : doc : doc
# 470 : awal : awal
# 471 : makai : maka
# 472 : btul : btul
# 473 : jg : jg
# 474 : konsulnya : konsul
# 475 : kedua : dua
# 476 : pesannya : pesan
# 477 : dimajuin : dimajuin
# 478 : bangun : bangun
# 479 : selesai : selesai
# 480 : ribu : ribu
# 481 : emg : emg
# 482 : rugi : rugi
# 483 : didapatkan : dapat
# 484 : tibatiba : tibatiba
# 485 : balas : balas
# 486 : tertulisnya : tulis
# 487 : tempat : tempat
# 488 : gimana : gimana
# 489 : bantuannya : bantu
# 490 : dong : dong
# 491 : hilang : hilang
# 492 : gitu : gitu
# 493 : rawat : rawat
# 494 : jalan : jalan
# 495 : kadang : kadang
# 496 : walau : walau
# 497 : ketemu : ketemu
# 498 : tatap : tatap
# 499 : muka : muka
# 500 : merasa : rasa
# 501 : kurang : kurang
# 502 : puas : puas
# 503 : penjelasan : jelas
# 504 : fleksibel : fleksibel
# 505 : dulu : dulu
# 506 : kejadian : jadi
# 507 : gizi : gizi
# 508 : belom : bom
# 509 : abis : abis
# 510 : jawab : jawab
# 511 : samsek : samsek
# 512 : pertanyaan : tanya
# 513 : lah : lah
# 514 : nungguin : nungguin
# 515 : ampek : ampek
# 516 : terbengong : bengong
# 517 : trus : trus
# 518 : dua : dua
# 519 : mendekati : dekat
# 520 : pdhl : pdhl
# 521 : agak : agak
# 522 : nyaman : nyaman
# 523 : menurut : turut
# 524 : solusinya : solusi
# 525 : yaaa : yaaa
# 526 : kinerja : kerja
# 527 : spt : spt
# 528 : bakal : bakal
# 529 : bngt : bngt
# 530 : biaya : biaya
# 531 : pun : pun
# 532 : bs : bs
# 533 : dipilih : pilih
# 534 : sesuai : sesuai
# 535 : kemampuan : mampu
# 536 : dr : dr
# 537 : adakan : adakan
# 538 : alfamartindomaret : alfamartindomaret
# 539 : memakai : pakai
# 540 : virual : virual
# 541 : lainnya : lain
# 542 : tepat : tepat
# 543 : mudahan : mudah
# 544 : pemilik : milik
# 545 : berikan : ikan
# 546 : kemudahan : mudah
# 547 : serta : serta
# 548 : amanah : amanah
# 549 : keluh : keluh
# 550 : kesah : kesah
# 551 : berkonsultasi : konsultasi
# 552 : namun : namun
# 553 : blm : blm
# 554 : membeli : beli
# 555 : area : area
# 556 : papua : papua
# 557 : khususnya : khusus
# 558 : timika : timika
# 559 : mohon : mohon
# 560 : sumpah : sumpah
# 561 : ribet : ribet
# 562 : estimasi : estimasi
# 563 : berubah : ubah
# 564 : mulu : mulu
# 565 : nyampe : nyampe
# 566 : kaga : kaga
# 567 : pokonya : poko
# 568 : penjelasannya : jelas
# 569 : komplit : komplit
# 570 : transfer : transfer
# 571 : virtual : virtual
# 572 : acount : acount
# 573 : krn : krn
# 574 : punya : punya
# 575 : dompet : dompet
# 576 : digitaldll : digitaldll
# 577 : digital : digital
# 578 : trkadang : trkadang
# 579 : keluarga : keluarga
# 580 : beda : beda
# 581 : lokasi : lokasi
# 582 : semoga : moga
# 583 : dipertahankan : tahan
# 584 : sgt : sgt
# 585 : update : update
# 586 : toko : toko
# 587 : psikolog : psikolog
# 588 : jdi : jdi
# 589 : pengobatannya : obat
# 590 : cocok : cocok
# 591 : terjangkau : jangkau
# 592 : membuat : buat
# 593 : jadwal : jadwal
# 594 : dibuka : buka
# 595 : kuota : kuota
# 596 : bintang : bintang
# 597 : dikirim : kirim
# 598 : kealamat : alamat
# 599 : id : id
# 600 : tiket : tiket
# 601 : untung : untung
# 602 : vitamin : vitamin
# 603 : bagaimana : bagaimana
# 604 : jika : jika
# 605 : asal : asal
# 606 : kirim : kirim
# 607 : contact : contact
# 608 : penerima : terima
# 609 : yes : yes
# 610 : ok : ok
# 611 : helodoc : helodoc
# 612 : membantuaplikasi : membantuaplikasi
# 613 : melayani : layan
# 614 : masyarakat : masyarakat
# 615 : kapan : kapan
# 616 : sambungin : sambungin
# 617 : nggak : nggak
# 618 : launching : launching
# 619 : sempet : sempet
# 620 : obrolannya : obrol
# 621 : bidang : bidang
# 622 : penyakit : sakit
# 623 : derita : derita
# 624 : ahli : ahli
# 625 : profesional : profesional
# 626 : gunakan : guna
# 627 : otomatis : otomatis
# 628 : pesen : sen
# 629 : ngaco : ngaco
# 630 : percuma : percuma
# 631 : instan : instan
# 632 : keperluan : perlu
# 633 : terpenuhi : penuh
# 634 : perhatikan : perhati
# 635 : kembali : kembali
# 636 : teliti : teliti
# 637 : saldonya : saldo
# 638 : mbangking : mbangking
# 639 : asuuu : asuuu
# 640 : masak : masak
# 641 : iya : iya
# 642 : abad : abad
# 643 : dateng : dateng
# 644 : ngebatalin : ngebatalin
# 645 : bisaa : bisaa
# 646 : emang : emang
# 647 : sengaja : sengaja
# 648 : gituu : gituu
# 649 : ngehubungin : ngehubungin
# 650 : apotiknya : apotik
# 651 : klo : klo
# 652 : sana : sana
# 653 : pakek : pakek
# 654 : serahin : serahin
# 655 : tugas : tugas
# 656 : jadinya : jadi
# 657 : kayak : kayak
# 658 : customer : customer
# 659 : berjamjam : berjamjam
# 660 : pembeli : beli
# 661 : adalah : adalah
# 662 : rajaratu : rajaratu
# 663 : sayya : sayya
# 664 : tetep : tetep
# 665 : pembaruan : baru
# 666 : elanjutnya : elanjutnya
# 667 : kami : kami
# 668 : cod : cod
# 669 : ngtd : ngtd
# 670 : bagusss : bagusss
# 671 : sat : sat
# 672 : set : set
# 673 : seru : seru
# 674 : diajak : ajak
# 675 : bareng : bareng
# 676 : pertama : pertama
# 677 : kendala : kendala
# 678 : hadapi : hadap
# 679 : segala : segala
# 680 : diikhtiarkan : ikhtiar
# 681 : salah : salah
# 682 : satunya : satu
# 683 : bismillah : bismillah
# 684 : pejuang : juang
# 685 : acne : acne
# 686 : semangat : semangat
# 687 : mengelola : kelola
# 688 : emosi : emosi
# 689 : informatif : informatif
# 690 : cari : cari
# 691 : kasihan : kasihan
# 692 : gojek : gojek
# 693 : nganter : nganter
# 694 : ujung : ujung
# 695 : balik : balik
# 696 : allah : allah
# 697 : kasian : kasi
# 698 : kang : kang
# 699 : ojek : ojek
# 700 : mantap : mantap
# 701 : biar : biar
# 702 : sehat : sehat
# 703 : hehe : hehe
# 704 : bangetbisa : bangetbisa
# 705 : aku : aku
# 706 : sakit : sakit
# 707 : sendiriandldqn : sendiriandldqn
# 708 : efektif : efektif
# 709 : efisien : efisien
# 710 : diberikan : beri
# 711 : terimakasi : terimakasi
# 712 : bahagia : bahagia
# 713 : diberi : beri
# 714 : umur : umur
# 715 : sll : sll
# 716 : memberi : beri
# 717 : pengobatan : obat
# 718 : sya : sya
# 719 : enak : enak
# 720 : badan : badan
# 721 : darurat : darurat
# 722 : sakita : sakita
# 723 : malas : malas
# 724 : berobat : obat
# 725 : akun : akun
# 726 : keterangan : terang
# 727 : jaringan : jaring
# 728 : anda : anda
# 729 : telah : telah
# 730 : sebanyak : banyak
# 731 : itupun : itu
# 732 : menunggu : tunggu
# 733 : melewati : lewat
# 734 : butuhnya : butuh
# 735 : penanganannya : tangan
# 736 : jelek : jelek
# 737 : begini : begini
# 738 : fotur : fotur
# 739 : dibalas : balas
# 740 : auto : auto
# 741 : bot : bot
# 742 : layak : layak
# 743 : pemilihan : pilih
# 744 : apoteknya : apotek
# 745 : direspon : direspon
# 746 : cuman : cuman
# 747 : responnya : responnya
# 748 : maksimal : maksimal
# 749 : cptdokter : cptdokter
# 750 : sdg : sdg
# 751 : diluar : luar
# 752 : kota : kota
# 753 : meminta : minta
# 754 : pertolongan : tolong
# 755 : rekomendasi : rekomendasi
# 756 : orangorang : orangorang
# 757 : berkomunikasi : komunikasi
# 758 : masyaa : masyaa
# 759 : terbantu : bantu
# 760 : apps : apps
# 761 : fiturnya : fiturnya
# 762 : lumayan : lumayan
# 763 : lengkap : lengkap
# 764 : beberapa : beberapa
# 765 : mencoba : coba
# 766 : manfaat : manfaat
# 767 : aamiin : aamiin
# 768 : yra : yra
# 769 : kak : kak
# 770 : diperhatikan : perhati
# 771 : liat : liat
# 772 : dimaps : dimaps
# 773 : mampir : mampir
# 774 : dal : dal
# 775 : memeriksa : periksa
# 776 : lokasinya : lokasi
# 777 : akurat : akurat
# 778 : tinggal : tinggal
# 779 : banten : banten
# 780 : bekasi : bekas
# 781 : adanya : ada
# 782 : pergi : pergi
# 783 : kerumah : rumah
# 784 : bahkan : bahkan
# 785 : murah : murah
# 786 : sejauh : jauh
# 787 : informasi : informasi
# 788 : sajikan : saji
# 789 : sangan : sangan
# 790 : hidup : hidup
# 791 : dipilihkan : pilih
# 792 : system : system
# 793 : ketersediaan : sedia
# 794 : stock : stock
# 795 : jaraknya : jarak
# 796 : disayangkan : sayang
# 797 : berbayar : bayar
# 798 : puyer : puyer
# 799 : terjemahan : terjemah
# 800 : google : google
# 801 : assalamualaikum : assalamualaikum
# 802 : tkw : tkw
# 803 : mengidap : idap
# 804 : kebenolan : kebenolan
# 805 : selangkangan : selangkang
# 806 : sebelah : belah
# 807 : kiri : kiri
# 808 : mengatasinya : atas
# 809 : mompresan : mompresan
# 810 : air : air
# 811 : hangat : hangat
# 812 : muncul : muncul
# 813 : dia : dia
# 814 : kambuh : kambuh
# 815 : perut : perut
# 816 : terasa : asa
# 817 : keram : keram
# 818 : saat : saat
# 819 : kompres : kompres
# 820 : benjolannya : benjol
# 821 : munculagi : munculagi
# 822 : dok : dok
# 823 : sementara : sementara
# 824 : indonesia : indonesia
# 825 : goodjob : goodjob
# 826 : krna : krna
# 827 : timbul : timbul
# 828 : mengambil : ambil
# 829 : tindakan : tindak
# 830 : cm : cm
# 831 : aplk : aplk
# 832 : asuransi : asuransi
# 833 : fwdsangat : fwdsangat
# 834 : mengingat : ingat
# 835 : pasca : pasca
# 836 : oprasi : oprasi
# 837 : apendiktapi : apendiktapi
# 838 : sayang : sayang
# 839 : ambil : ambil
# 840 : radius : radius
# 841 : jauhpadahal : jauhpadahal
# 842 : jatinangorkasian : jatinangorkasian
# 843 : nyatolong : nyatolong
# 844 : bantu : bantu
# 845 : setiap : tiap
# 846 : alamat : alamat
# 847 : pengalamanku : alam
# 848 : bangetdokter : bangetdokter
# 849 : menjelaskan : jelas
# 850 : deh : deh
# 851 : dimana : mana
# 852 : kapanpun : kapan
# 853 : para : para
# 854 : ahlinya : ahli
# 855 : membatu : batu
# 856 : bersih : bersih
# 857 : terawat : awat
# 858 : astrid : astrid
# 859 : kira : kira
# 860 : fitbest : fitbest
# 861 : kadaluwarsaternyata : kadaluwarsaternyata
# 862 : lihat : lihat
# 863 : expired : expired
# 864 : sekalidokternyapun : sekalidokternyapun
# 865 : barangnya : barang
# 866 : teratasi : atas
# 867 : panik : panik
# 868 : tanya : tanya
# 869 : jelaskan : jelas
# 870 : secara : cara
# 871 : berselisih : selisih
# 872 : hal : hal
# 873 : msih : msih
# 874 : muter : muter
# 875 : link : link
# 876 : ajashg : ajashg
# 877 : tak : tak
# 878 : pemakai : pakai
# 879 : trims : trims
# 880 : diare : diare
# 881 : anak : anak
# 882 : lamaaa : lamaaa
# 883 : bgt : bgt
# 884 : pake : pake
# 885 : ngambil : ngambil
# 886 : bagustp : bagustp
# 887 : paling : paling
# 888 : sini : sini
# 889 : menemukan : temu
# 890 : solusijadi : solusijadi
# 891 : uangnya : uang
# 892 : superduper : superduper
# 893 : diandalkan : andal
# 894 : mendadak : dadak
# 895 : emergency : emergency
# 896 : anytime : anytime
# 897 : umum : umum
# 898 : specialis : specialis
# 899 : appreciated : appreciated
# 900 : bapak : bapak
# 901 : ibu : ibu
# 902 : terkait : kait
# 903 : menu : menu
# 904 : kalender : kalender
# 905 : menstruasi : menstruasi
# 906 : bud : bud
# 907 : nanti : nanti
# 908 : luar : luar
# 909 : biasa : biasa
# 910 : tua : tua
# 911 : kondisi : kondisi
# 912 : memerlukan : perlu
# 913 : berjasa : jasa
# 914 : rusak : rusak
# 915 : pengaruh : pengaruh
# 916 : handphone : handphone
# 917 : mempunyai : punya
# 918 : peloksok : peloksok
# 919 : bersahabat : sahabat
# 920 : memberikan : beri
# 921 : cukup : cukup
# 922 : blum : blum
# 923 : fasilitas : fasilitas
# 924 : by : by
# 925 : menyambungkan : sambung
# 926 : perlu : perlu
# 927 : buru : buru
# 928 : mendapatkan : dapat
# 929 : inilah : ini
# 930 : fungsi : fungsi
# 931 : teknologi : teknologi
# 932 : sesungguhnya : sungguh
# 933 : hallo : hallo
# 934 : so : so
# 935 : far : far
# 936 : metode : metode
# 937 : pembayarannya : bayar
# 938 : kepotong : potong
# 939 : notifikasi : notifikasi
# 940 : payah : payah
# 941 : account : account
# 942 : dibls : dibls
# 943 : dijawab : jawab
# 944 : pahami : paham
# 945 : resepkan : resep
# 946 : thanks : thanks
# 947 : yah : yah
# 948 : resepnya : resep
# 949 : mengatasi : atas
# 950 : dimanapun : mana
# 951 : posisi : posisi
# 952 : berada : ada
# 953 : sebagai : bagai
# 954 : pemula : mula
# 955 : memanjakan : manja
# 956 : sbg : sbg
# 957 : kebingungan : bingung
# 958 : mencari : cari
# 959 : lasih : lasih
# 960 : pangirimannya : pangirimannya
# 961 : thankyou : thankyou
# 962 : sanggatt : sanggatt
# 963 : penemuan : temu
# 964 : jugajadi : jugajadi
# 965 : cape : cape
# 966 : kesana : kesana
# 967 : kemari : kemari
# 968 : sebenarnya : benar
# 969 : spesialisnya : spesialis
# 970 : merata : rata
# 971 : spesialis : spesialis
# 972 : tiap : tiap
# 973 : kotaprovinsi : kotaprovinsi
# 974 : contoh : contoh
# 975 : daerah : daerah
# 976 : ciayumajakuning : ciayumajakuning
# 977 : jawa : jawa
# 978 : barat : barat
# 979 : tersedia : sedia
# 980 : az : az
# 981 : calon : calon
# 982 : misalnya : misal
# 983 : operasi : operasi
# 984 : menangani : tangan
# 985 : tersebut : sebut
# 986 : jawaban : jawab
# 987 : berakhir : akhir
# 988 : apapun : apa
# 989 : nomor : nomor
# 990 : ferivikasi : ferivikasi
# 991 : ribetlelet : ribetlelet
# 992 : rekomen : rekomen
# 993 : flexibel : flexibel
# 994 : dimengerti : erti
# 995 : bangettt : bangettt
# 996 : out : out
# 997 : sekalian : sekali
# 998 : bentuk : bentuk
# 999 : dilihat : lihat
# 1000 : digunakan : guna
# 1001 : mental : mental
# 1002 : diakses : akses
# 1003 : tekan : tekan
# 1004 : beranda : beranda
# 1005 : sedangkan : sedang
# 1006 : trmksh : trmksh
# 1007 : pengingat : ingat
# 1008 : selengkap : lengkap
# 1009 : ios : ios
# 1010 : dipakai : pakai
# 1011 : diresepnya : resep
# 1012 : dikembangkan : kembang
# 1013 : durasi : durasi
# 1014 : pembodohan : bodoh
# 1015 : laama : laama
# 1016 : percakapan : cakap
# 1017 : sia : sia
# 1018 : msh : msh
# 1019 : sblh : sblh
# 1020 : keluarin : keluarin
# 1021 : dlm : dlm
# 1022 : mengakhiri : akhir
# 1023 : plus : plus
# 1024 : unfaedah : unfaedah
# 1025 : masukan : masuk
# 1026 : pengembangan : kembang
# 1027 : konfirmasi : konfirmasi
# 1028 : no : no
# 1029 : hp : hp
# 1030 : detik : detik
# 1031 : seriously : seriously
# 1032 : sms : sms
# 1033 : sdh : sdh
# 1034 : bye : bye
# 1035 : fever : fever
# 1036 : diarahin : diarahin
# 1037 : jdinya : jdinya
# 1038 : pick : pick
# 1039 : sekalinya : sekali
# 1040 : sampenya : sampenya
# 1041 : sendirian : sendiri
# 1042 : rantau : rantau
# 1043 : terutama : utama
# 1044 : permintaan : minta
# 1045 : surat : surat
# 1046 : menyediakan : sedia
# 1047 : range : range
# 1048 : biayanya : biaya
# 1049 : termasuk : masuk
# 1050 : voucher : voucher
# 1051 : diskon : diskon
# 1052 : gratis : gratis
# 1053 : uiux : uiux
# 1054 : user : user
# 1055 : pakehome : pakehome
# 1056 : visitnya : visitnya
# 1057 : apknya : apknya
# 1058 : refrensi : refrensi
# 1059 : pengalam : alam
# 1060 : menjabarkan : jabar
# 1061 : penjelasaanya : penjelasaanya
# 1062 : selebihnya : lebih
# 1063 : biru : biru
# 1064 : menolong : tolong
# 1065 : bila : bila
# 1066 : mendengarkan : dengar
# 1067 : luarbiasa : luarbiasa
# 1068 : tipu : tipu
# 1069 : rekomended : rekomended
# 1070 : menampilkan : tampil
# 1071 : nilai : nilai
# 1072 : disetiap : tiap
# 1073 : baiknya : baik
# 1074 : komentar : komentar
# 1075 : jasa : jasa
# 1076 : terciptanya : cipta
# 1077 : transparansi : transparansi
# 1078 : menyeluruh : seluruh
# 1079 : rantauan : rantau
# 1080 : ringan : ringan
# 1081 : menyebar : sebar
# 1082 : keseluruh : seluruh
# 1083 : bekerjasama : bekerjasama
# 1084 : per : per
# 1085 : daerahnya : daerah
# 1086 : merantau : rantau
# 1087 : gbsa : gbsa
# 1088 : kedokter : dokter
# 1089 : sendiri : sendiri
# 1090 : bagussssss : bagussssss
# 1091 : keadaan : ada
# 1092 : td : td
# 1093 : beralih : alih
# 1094 : trouble : trouble
# 1095 : endingnya : endingnya
# 1096 : suara : suara
# 1097 : digerakin : digerakin
# 1098 : dipencet : pencet
# 1099 : option : option
# 1100 : ttp : ttp
# 1101 : keren : keren
# 1102 : ilmu : ilmu
# 1103 : email : email
# 1104 : telpon : telpon
# 1105 : konselin : konselin
# 1106 : tempst : tempst
# 1107 : telepon : telepon
# 1108 : otc : otc
# 1109 : ready : ready
# 1110 : terkena : kena
# 1111 : covid : covid
# 1112 : satusatunya : satusatunya
# 1113 : tebus : tebus
# 1114 : mendapat : dapat
# 1115 : diagnosa : diagnosa
# 1116 : disarankan : saran
# 1117 : dibatalinngubah : dibatalinngubah
# 1118 : segera : segera
# 1119 : pembelian : beli
# 1120 : terlalu : terlalu
# 1121 : singkat : singkat
# 1122 : atm : atm
# 1123 : pindah : pindah
# 1124 : upgrade : upgrade
# 1125 : diresepkan : resep
# 1126 : edit : edit
# 1127 : bersangkutan : sangkut
# 1128 : ditemukan : temu
# 1129 : bekerja : kerja
# 1130 : terkendala : kendala
# 1131 : stok : stok
# 1132 : respek : respek
# 1133 : pekerja : kerja
# 1134 : sperti : sperti
# 1135 : siapa : siapa
# 1136 : menjawab : jawab
# 1137 : trimakasih : trimakasih
# 1138 : disemua : semua
# 1139 : kosong : kosong
# 1140 : kirain : kirain
# 1141 : perbayar : bayar
# 1142 : bertnya : bertnya
# 1143 : tadi : tadi
# 1144 : tetapi : tetapi
# 1145 : tersambung : sambung
# 1146 : bersifat : sifat
# 1147 : basabasikurang : basabasikurang
# 1148 : cerita : cerita
# 1149 : dibaca : baca
# 1150 : penyampaian : sampai
# 1151 : penggunaan : guna
# 1152 : dll : dll
# 1153 : obatan : obat
# 1154 : harganya : harga
# 1155 : memasukan : pasu
# 1156 : tentukan : tentu
# 1157 : supaya : supaya
# 1158 : daftarpadahal : daftarpadahal
# 1159 : verifikasi : verifikasi
# 1160 : kirimkan : kirim
# 1161 : ongkirnya : ongkirnya
# 1162 : sdkt : sdkt
# 1163 : hrga : hrga
# 1164 : kdg : kdg
# 1165 : borongan : borong
# 1166 : keputus : putus
# 1167 : lg : lg
# 1168 : mgkn : mgkn
# 1169 : koneksinya : koneksi
# 1170 : tk : tk
# 1171 : koperatif : koperatif
# 1172 : iniselain : iniselain
# 1173 : mengantarkan : antar
# 1174 : batuk : batuk
# 1175 : paten : paten
# 1176 : hallodok : hallodok
# 1177 : adaa : adaa
# 1178 : pakaiii : pakaiii
# 1179 : ayoo : ayoo
# 1180 : halodok : halodok
# 1181 : lagii : lagi
# 1182 : penggunaany : penggunaany
# 1183 : mimin : mimin
# 1184 : si : si
# 1185 : kecuali : kecuali
# 1186 : apakah : apakah
# 1187 : meyakinkan : yakin
# 1188 : min : min
# 1189 : penyelesainya : selesa
# 1190 : khawatir : khawatir
# 1191 : dipahami : paham
# 1192 : ahki : ahki
# 1193 : cocokaplikasi : cocokaplikasi
# 1194 : benarbenar : benarbenar
# 1195 : membantuterima : membantuterima
# 1196 : shipper : shipper
# 1197 : alihkan : alih
# 1198 : sigesit : sigesit
# 1199 : iini : iini
# 1200 : nga : nga
# 1201 : recomend : recomend
# 1202 : paket : paket
# 1203 : titip : titip
# 1204 : lambat : lambat
# 1205 : dsni : dsni
# 1206 : modar : modar
# 1207 : duluan : duluan
# 1208 : kubur : kubur
# 1209 : pemeriksaan : periksa
# 1210 : nakes : nakes
# 1211 : professional : professional
# 1212 : siang : siang
# 1213 : hasilnya : hasil
# 1214 : era : era
# 1215 : digitalisasi : digitalisasi
# 1216 : good : good
# 1217 : job : job
# 1218 : selisih : selisih
# 1219 : bidannya : bidan
# 1220 : gercep : gercep
# 1221 : slow : slow
# 1222 : mungkin : mungkin
# 1223 : istirahat : istirahat
# 1224 : ongkir : ongkir
# 1225 : drpada : drpada
# 1226 : diantarkan : antar
# 1227 : orderan : order
# 1228 : terbuka : buka
# 1229 : terhadap : hadap
# 1230 : pertanyaana : pertanyaana
# 1231 : pasie : pasie
# 1232 : ditanggapi : tanggap
# 1233 : dirumah : rumah
# 1234 : tip : tip
# 1235 : lapor : lapor
# 1236 : berat : berat
# 1237 : kamu : kamu
# 1238 : senin : senin
# 1239 : perkiraan : kira
# 1240 : sabtu : sabtu
# 1241 : dtgnya : dtgnya
# 1242 : engga : engga
# 1243 : disuruh : suruh
# 1244 : besoknya : besok
# 1245 : instannya : instan
# 1246 : meninggalkan : tinggal
# 1247 : baby : baby
# 1248 : trx : trx
# 1249 : swadaya : swadaya
# 1250 : rekomend : rekomend
# 1251 : nanto : nanto
# 1252 : dhe : dhe
# 1253 : best : best
# 1254 : poko : poko
# 1255 : nyaaa : nyaaa
# 1256 : percepat : cepat
# 1257 : an : an
# 1258 : minum : minum
# 1259 : berlangganan : langgan
# 1260 : jaka : jaka
# 1261 : kurniawan : kurniawan
# 1262 : beliau : beliau
# 1263 : alhamdulillaah : alhamdulillaah
# 1264 : tanggap : tanggap
# 1265 : sempat : sempat
# 1266 : rmh : rmh
# 1267 : langsng : langsng
# 1268 : mantapp : mantapp
# 1269 : dikala : kala
# 1270 : nggakbisa : nggakbisa
# 1271 : lgsg : lgsg
# 1272 : tentuin : tentuin
# 1273 : listnya : listnya
# 1274 : fastrespon : fastrespon
# 1275 : sembuh : sembuh
# 1276 : thank : thank
# 1277 : you : you
# 1278 : fast : fast
# 1279 : repotrepot : repotrepot
# 1280 : klinik : klinik
# 1281 : tulasan : tulasan
# 1282 : cover : cover
# 1283 : tombol : tombol
# 1284 : pesaman : pesam
# 1285 : dikasi : kasi
# 1286 : keempat : empat
# 1287 : service : service
# 1288 : menggunanakan : menggunanakan
# 1289 : langganan : langgan
# 1290 : enam : enam
# 1291 : dinaikan : naik
# 1292 : pemberitahuan : pemberitahuan
# 1293 : kepada : kepada
# 1294 : expire : expire
# 1295 : desember : desember
# 1296 : maaf : maaf
# 1297 : point : point
# 1298 : disepakati : pakat
# 1299 : kenaikan : naik
# 1300 : pemberithauan : pemberithauan
# 1301 : hati : hati
# 1302 : terangterangan : terangterangan
# 1303 : tambahan : tambah
# 1304 : hambatan : hambat
# 1305 : periksa : periksa
# 1306 : kasii : kasi
# 1307 : kepikiran : pikir
# 1308 : ketahui : tahu
# 1309 : sekalikonsulnya : sekalikonsulnya
# 1310 : makasih : makasih
# 1311 : bergabung : gabung
# 1312 : makin : makin
# 1313 : raja : raja
# 1314 : tina : tina
# 1315 : mengerti : erti
# 1316 : belanja : belanja
# 1317 : canggih : canggih
# 1318 : setting : setting
# 1319 : pribadi : pribadi
# 1320 : siaga : siaga
# 1321 : tmpt : tmpt
# 1322 : faskes : faskes
# 1323 : memiliki : milik
# 1324 : sy : sy
# 1325 : nda : nda
# 1326 : slm : slm
# 1327 : heleh : heleh
# 1328 : gagal : gagal
# 1329 : masukkan : masuk
# 1330 : keranjang : keranjang
# 1331 : bebas : bebas
# 1332 : kantor : kantor
# 1333 : ngelink : ngelink
# 1334 : jafi : jafi
# 1335 : dicover : dicover
# 1336 : berhari : hari
# 1337 : mati : mati
# 1338 : mendesak : desak
# 1339 : agustus : agustus
# 1340 : bilangin : bilangin
# 1341 : gomed : gomed
# 1342 : error : error
# 1343 : masalahnya : masalah
# 1344 : resi : resi
# 1345 : sensor : sensor
# 1346 : resinya : resi
# 1347 : lacaknya : lacak
# 1348 : bodoh : bodoh
# 1349 : gambar : gambar
# 1350 : thumbnail : thumbnail
# 1351 : burik : burik
# 1352 : buram : buram
# 1353 : full : full
# 1354 : hd : hd
# 1355 : ragu : ragu
# 1356 : berapa : berapa
# 1357 : kuantitas : kuantitas
# 1358 : komposisi : komposisi
# 1359 : konflik : konflik
# 1360 : deskripsi : deskripsi
# 1361 : search : search
# 1362 : konsumen : konsumen
# 1363 : kreatif : kreatif
# 1364 : keywordnya : keywordnya
# 1365 : perubahan : ubah
# 1366 : majalaya : majalaya
# 1367 : garut : garut
# 1368 : kayaknya : kayak
# 1369 : efek : efek
# 1370 : besar : besar
# 1371 : repeat : repeat
# 1372 : aduh : aduh
# 1373 : menyanggupi : sanggup
# 1374 : gaenak : gaenak
# 1375 : cancelnya : cancelnya
# 1376 : diterima : terima
# 1377 : haduhhh : haduhhh
# 1378 : semakin : makin
# 1379 : simple : simple
# 1380 : lamaa : lamaa
# 1381 : tks : tks
# 1382 : gabisa : gabisa
# 1383 : verifikasinya : verifikasi
# 1384 : dilacak : lacak
# 1385 : gaada : gaada
# 1386 : gatau : gatau
# 1387 : robot : robot
# 1388 : template : template
# 1389 : sebaiknya : baik
# 1390 : jgn : jgn
# 1391 : logoutbisa : logoutbisa
# 1392 : matingdrop : matingdrop
# 1393 : memakan : makan
# 1394 : ditingkatkankalau : ditingkatkankalau
# 1395 : ditambah : tambah
# 1396 : didalamnya : dalam
# 1397 : diantara : antara
# 1398 : onsupaya : onsupaya
# 1399 : mengulang : ulang
# 1400 : trimksh : trimksh
# 1401 : halodocsukses : halodocsukses
# 1402 : nyoba : nyoba
# 1403 : luka : luka
# 1404 : kecil : kecil
# 1405 : daruratpembayaran : daruratpembayaran
# 1406 : digitalresep : digitalresep
# 1407 : terjangkaupertma : terjangkaupertma
# 1408 : minim : minim
# 1409 : budget : budget
# 1410 : antri : antri
# 1411 : dlu : dlu
# 1412 : mngingat : mngingat
# 1413 : tanggapan : tanggap
# 1414 : agen : agen
# 1415 : docnya : docnya
# 1416 : psanan : psanan
# 1417 : krim : krim
# 1418 : terbatalkan : batal
# 1419 : lgi : lgi
# 1420 : bertele : tele
# 1421 : bgd : bgd
# 1422 : merespon : merespon
# 1423 : aktif : aktif
# 1424 : trim : trim
# 1425 : cristine : cristine
# 1426 : spa : spa
# 1427 : ku : ku
# 1428 : kelemahanya : kelemahanya
# 1429 : satuuntuk : satuuntuk
# 1430 : titik : titik
# 1431 : mapsjadi : mapsjadi
# 1432 : realnyamohon : realnyamohon
# 1433 : pemesan : mes
# 1434 : mapsselebihnya : mapsselebihnya
# 1435 : cepatsangat : cepatsangat
# 1436 : genting : genting
# 1437 : bth : bth
# 1438 : perban : perban
# 1439 : bekas : bekas
# 1440 : op : op
# 1441 : jantung : jantung
# 1442 : mama : mama
# 1443 : langanan : langanan
# 1444 : adacoba : adacoba
# 1445 : donk : donk
# 1446 : taunya : tau
# 1447 : gara : gara
# 1448 : back : back
# 1449 : panas : panas
# 1450 : pula : pula
# 1451 : thx : thx
# 1452 : berterima : terima
# 1453 : bnget : bnget
# 1454 : ngarahin : ngarahin
# 1455 : akusangat : akusangat
# 1456 : gua : gua
# 1457 : ngasih : ngasih
# 1458 : rasakan : rasa
# 1459 : dimaximalkan : dimaximalkan
# 1460 : komunikatifterima : komunikatifterima
# 1461 : dokterterima : dokterterima
# 1462 : sangatlah : sangat
# 1463 : media : media
# 1464 : disediakan : sedia
# 1465 : ui : ui
# 1466 : vcnya : vcnya
# 1467 : perjelas : jelas
# 1468 : terselip : selip
# 1469 : icon : icon
# 1470 : tiik : tiik
# 1471 : tiga : tiga
# 1472 : alangkah : alangkah
# 1473 : dimunculin : dimunculin
# 1474 : atas : atas
# 1475 : kanan : kanan
# 1476 : space : space
# 1477 : manfaatkan : manfaat
# 1478 : gampang : gampang
# 1479 : baikbaik : baikbaik
# 1480 : psikiater : psikiater
# 1481 : tunggu : tunggu
# 1482 : pencet : pencet
# 1483 : ilang : ilang
# 1484 : hangus : hangus
# 1485 : baikrespon : baikrespon
# 1486 : bgitu : bgitu
# 1487 : sngat : sngat
# 1488 : senang : senang
# 1489 : disini : sini
# 1490 : diupdate : diupdate
# 1491 : topup : topup
# 1492 : marketplace : marketplace
# 1493 : terkenal : kenal
# 1494 : spti : spti
# 1495 : shpee : shpee
# 1496 : tokopdia : tokopdia
# 1497 : darimana : darimana
# 1498 : mini : mini
# 1499 : market : market
# 1500 : pasti : pasti
# 1501 : laris : laris
# 1502 : pemakaian : pakai
# 1503 : ditulis : tulis
# 1504 : rsklinik : rsklinik
# 1505 : dimiliki : milik
# 1506 : sempit : sempit
# 1507 : sulit : sulit
# 1508 : mendukung : dukung
# 1509 : kluar : kluar
# 1510 : brobat : brobat
# 1511 : acvount : acvount
# 1512 : tib : tib
# 1513 : ramahpengantaran : ramahpengantaran
# 1514 : cepataplikasi : cepataplikasi
# 1515 : ketimbang : ketimbang
# 1516 : off : off
# 1517 : line : line
# 1518 : terusss : terusss
# 1519 : otp : otp
# 1520 : pke : pke
# 1521 : beresp : beresp
# 1522 : merawat : rawat
# 1523 : suamiterima : suamiterima
# 1524 : penting : penting
# 1525 : kaum : kaum
# 1526 : mager : mager
# 1527 : krmh : krmh
# 1528 : sebab : sebab
# 1529 : sembarangan : sembarang
# 1530 : tulis : tulis
# 1531 : tangan : tangan
# 1532 : tolol : tolol
# 1533 : bedanya : beda
# 1534 : pokoknya : pokok
# 1535 : lh : lh
# 1536 : hewannya : hewan
# 1537 : burung : burung
# 1538 : kolongan : kolong
# 1539 : youtube : youtube
# 1540 : hewankurang : hewankurang
# 1541 : hewan : hewan
# 1542 : kesayangan : sayang
# 1543 : dara : dara
# 1544 : dapt : dapt
# 1545 : sebenenya : sebenenya
# 1546 : ngehang : ngehang
# 1547 : capecape : capecape
# 1548 : klikklik : klikklik
# 1549 : isiisi : isiisi
# 1550 : identitas : identitas
# 1551 : ngulang : ngulang
# 1552 : kaya : kaya
# 1553 : gituuuu : gituuuu
# 1554 : ori : ori
# 1555 : bersaing : saing
# 1556 : kemarin : kemarin
# 1557 : isu : isu
# 1558 : mengenakkan : enak
# 1559 : soal : soal
# 1560 : legalitas : legalitas
# 1561 : berdasar : dasar
# 1562 : regulasi : regulasi
# 1563 : tentang : tentang
# 1564 : mengenai : kena
# 1565 : permudah : mudah
# 1566 : halodic : halodic
# 1567 : namunkedepannya : namunkedepannya
# 1568 : akses : akses
# 1569 : jangkauan : jangkau
# 1570 : scra : scra
# 1571 : pedesaan : desa
# 1572 : ditingkatkan : tingkat
# 1573 : pusat : pusat
# 1574 : jangkau : jangkau
# 1575 : waw : waw
# 1576 : hallodoc : hallodoc
# 1577 : smoga : smoga
# 1578 : inu : inu
# 1579 : next : next
# 1580 : time : time
# 1581 : excellent : excellent
# 1582 : im : im
# 1583 : sorry : sorry
# 1584 : to : to
# 1585 : say : say
# 1586 : my : my
# 1587 : bad : bad
# 1588 : review : review
# 1589 : for : for
# 1590 : conslutation : conslutation
# 1591 : membayar : bayar
# 1592 : erizal : erizal
# 1593 : azmi : azmi
# 1594 : first : first
# 1595 : impression : impression
# 1596 : me : me
# 1597 : humanis : humanis
# 1598 : trima : trima
# 1599 : datangnya : datang
# 1600 : sejam : jam
# 1601 : apotekknya : apotekknya
# 1602 : dihubungin : dihubungin
# 1603 : admin : admin
# 1604 : bangett : bangett
# 1605 : halodog : halodog
# 1606 : knp : knp
# 1607 : hape : hape
# 1608 : loh : loh
# 1609 : servernya : servernya
# 1610 : apany : apany
# 1611 : napa : napa
# 1612 : org : org
# 1613 : dibuat : buat
# 1614 : ni : ni
# 1615 : heran : heran
# 1616 : cobain : cobain
# 1617 : percobaan : coba
# 1618 : ketiga : tiga
# 1619 : tentu : tentu
# 1620 : bpjs : bpjs
# 1621 : bakalan : bakal
# 1622 : caranya : cara
# 1623 : emnk : emnk
# 1624 : ajarin : ajarin
# 1625 : ntar : ntar
# 1626 : naikkin : naikkin
# 1627 : ratingnya : ratingnya
# 1628 : dibidangnya : bidang
# 1629 : maslaah : maslaah
# 1630 : dtg : dtg
# 1631 : menarik : tarik
# 1632 : dibantu : bantu
# 1633 : berpengalaman : alam
# 1634 : membuka : buka
# 1635 : ruang : ruang
# 1636 : dikit : dikit
# 1637 : lab : lab
# 1638 : baca : baca
# 1639 : mas : mas
# 1640 : aga : aga
# 1641 : manual : manual
# 1642 : lebaran : lebaran
# 1643 : kuda : kuda
# 1644 : terintegrasi : integrasi
# 1645 : optimal : optimal
# 1646 : melainkan : lain
# 1647 : justru : justru
# 1648 : menyusahkan : susah
# 1649 : seringkali : seringkali
# 1650 : terjadi : jadi
# 1651 : bugs : bugs
# 1652 : specials : specials
# 1653 : case : case
# 1654 : skenario : skenario
# 1655 : sekaliingin : sekaliingin
# 1656 : drh : drh
# 1657 : halodocharga : halodocharga
# 1658 : bervarian : varian
# 1659 : bisalalu : bisalalu
# 1660 : check : check
# 1661 : cancle : cancle
# 1662 : yakali : yakali
# 1663 : raya : raya
# 1664 : melebihi : lebih
# 1665 : batas : batas
# 1666 : sebelumnya : belum
# 1667 : semenjak : semenjak
# 1668 : diganti : ganti
# 1669 : ditempat : tempat
# 1670 : dengerin : dengerin
# 1671 : aspirasi : aspirasi
# 1672 : meski : meski
# 1673 : pelosok : pelosok
# 1674 : disitu : situ
# 1675 : dibilang : bilang
# 1676 : bahwa : bahwa
# 1677 : membatalkan : batal
# 1678 : pertemuan : temu
# 1679 : gratisobat : gratisobat
# 1680 : baikrecomended : baikrecomended
# 1681 : oba : oba
# 1682 : alkes : alkes
# 1683 : scr : scr
# 1684 : on : on
# 1685 : cepatpengiriman : cepatpengiriman
# 1686 : sartika : sartika
# 1687 : yauda : yauda
# 1688 : batalin : batalin
# 1689 : dikira : kira
# 1690 : gajelas : gajelas
# 1691 : tanggapi : tanggap
# 1692 : independen : independen
# 1693 : layanannya : layan
# 1694 : bsa : bsa
# 1695 : flexible : flexible
# 1696 : favorit : favorit
# 1697 : mahdi : mahdi
# 1698 : supercepat : supercepat
# 1699 : mengalami : alami
# 1700 : kerugian : rugi
# 1701 : konsultasiiiiii : konsultasiiiiii
# 1702 : penbayaran : penbayaran
# 1703 : harap : harap
# 1704 : pertanggung : tanggung
# 1705 : terkirim : kirim
# 1706 : komunikatif : komunikatif
# 1707 : ramahdan : ramahdan
# 1708 : terjangkaubagus : terjangkaubagus
# 1709 : ngebantu : ngebantu
# 1710 : nyeselll : nyeselll
# 1711 : kapok : kapok
# 1712 : sinih : sih
# 1713 : vocer : vocer
# 1714 : dipake : dipake
# 1715 : lngsung : lngsung
# 1716 : effendy : effendy
# 1717 : gunawan : gunawan
# 1718 : sp : sp
# 1719 : og : og
# 1720 : runtut : runtut
# 1721 : liburan : libur
# 1722 : merchant : merchant
# 1723 : anggap : anggap
# 1724 : sepeti : sepet
# 1725 : tertipu : tipu
# 1726 : praktisdan : praktisdan
# 1727 : tenang : tenang
# 1728 : baguss : baguss
# 1729 : hipertensi : hipertensi
# 1730 : penyempitan : sempit
# 1731 : suplemen : suplemen
# 1732 : tahun : tahun
# 1733 : chatnya : chatnya
# 1734 : berisik : berisik
# 1735 : kek : kek
# 1736 : tgl : tgl
# 1737 : beres : beres
# 1738 : alasannya : alas
# 1739 : mnggunakan : mnggunakan
# 1740 : jwab : jwab
# 1741 : chatingan : chatingan
# 1742 : doi : doi
# 1743 : gila : gila
# 1744 : beretitud : beretitud
# 1745 : sharelock : sharelock
# 1746 : alamatnya : alamat
# 1747 : sdah : sdah
# 1748 : bner : bner
# 1749 : maps : maps
# 1750 : jaringannya : jaring
# 1751 : stabil : stabil
# 1752 : marah : marah
# 1753 : kaynya : kaynya
# 1754 : dikirimnya : kirim
# 1755 : mapnya : map
# 1756 : seharusnya : harus
# 1757 : support : support
# 1758 : cepatmantab : cepatmantab
# 1759 : download : download
# 1760 : shopeepay : shopeepay
# 1761 : dibutuhkan : butuh
# 1762 : hebatt : hebatt
# 1763 : diresepin : diresepin
# 1764 : kerenn : kerenn
# 1765 : responmantapp : responmantapp
# 1766 : wajib : wajib
# 1767 : jamin : jamin
# 1768 : nyesel : nyesel
# 1769 : berguna : guna
# 1770 : kos : kos
# 1771 : kesalahan : salah
# 1772 : gemes : gemes
# 1773 : exp : exp
# 1774 : ketarangan : tarang
# 1775 : gopaylater : gopaylater
# 1776 : dilakukan : laku
# 1777 : halodocsangat : halodocsangat
# 1778 : mulai : mulai
# 1779 : kecantikan : cantik
# 1780 : rivo : rivo
# 1781 : rama : rama
# 1782 : byk : byk
# 1783 : potongan : potong
# 1784 : pertahankan : tahan
# 1785 : tambahkan : tambah
# 1786 : shinta : shinta
# 1787 : dewi : dewi
# 1788 : rahmadhani : rahmadhani
# 1789 : temanhidupsehat : temanhidupsehat
# 1790 : baikalhamdulillah : baikalhamdulillah
# 1791 : terbaik : baik
# 1792 : berdasarkan : dasar
# 1793 : memikirkan : pikir
# 1794 : ditanyakan : tanya
# 1795 : berfikir : berfikir
# 1796 : antre : antre
# 1797 : sekedar : dar
# 1798 : mengetahui : tahu
# 1799 : geratis : gerat
# 1800 : apalah : apa
# 1801 : daya : daya
# 1802 : peanguran : peanguran
# 1803 : makan : makan
# 1804 : aza : aza
# 1805 : gx : gx
# 1806 : naya : naya
# 1807 : hrs : hrs
# 1808 : ampun : ampun
# 1809 : diperkirakan : kira
# 1810 : obatnyaapalagi : obatnyaapalagi
# 1811 : bnilife : bnilife
# 1812 : trimakasiih : trimakasiih
# 1813 : mengecewakanresponnya : mengecewakanresponnya
# 1814 : langsungcukup : langsungcukup
# 1815 : memesan : mes
# 1816 : stuck : stuck
# 1817 : blom : blom
# 1818 : dicancel : dicancel
# 1819 : tulisan : tulis
# 1820 : jadwalnya : jadwal
# 1821 : komplain : komplain
# 1822 : partner : partner
# 1823 : sekalipun : sekalipun
# 1824 : seneng : neng
# 1825 : tf : tf
# 1826 : pengen : ken
# 1827 : dadakan : dada
# 1828 : ternyta : ternyta
# 1829 : syukurnya : syukur
# 1830 : se : se
# 1831 : walaupun : walaupun
# 1832 : instant : instant
# 1833 : umumspahli : umumspahli
# 1834 : gizisampai : gizisampai
# 1835 : smw : smw
# 1836 : hebatobat : hebatobat
# 1837 : diksih : diksih
# 1838 : gol : gol
# 1839 : generik : generik
# 1840 : bagustingkat : bagustingkat
# 1841 : ind : ind
# 1842 : mantab : mantab
# 1843 : kebantu : bantu
# 1844 : borzo : borzo
# 1845 : wd : wd
# 1846 : ganti : ganti
# 1847 : it : it
# 1848 : kam : kam
# 1849 : bilang : bilang
# 1850 : terhubung : hubung
# 1851 : free : free
# 1852 : log : log
# 1853 : in : in
# 1854 : sangatsangat : sangatsangat
# 1855 : ortujadi : ortujadi
# 1856 : ortu : ortu
# 1857 : obatlangsung : obatlangsung
# 1858 : cuzz : cuzz
# 1859 : halodockeren : halodockeren
# 1860 : ulasan : ulas
# 1861 : tadinya : tadi
# 1862 : garis : garis
# 1863 : bawahi : bawah
# 1864 : sertakan : serta
# 1865 : menghambat : hambat
# 1866 : seumur : umur
# 1867 : dosis : dosis
# 1868 : total : total
# 1869 : tireidektomi : tireidektomi
# 1870 : arahkan : arah
# 1871 : euthyrox : euthyrox
# 1872 : matikan : mati
# 1873 : pa : pa
# 1874 : membuktikan : bukti
# 1875 : staff : staff
# 1876 : seenaknya : enak
# 1877 : selaku : selaku
# 1878 : prihal : prihal
# 1879 : bermaslah : mas
# 1880 : maksudnya : maksud
# 1881 : pembaharuan : baharu
# 1882 : ikutin : ikutin
# 1883 : lacak : lacak
# 1884 : pesanannya : pesan
# 1885 : ditrace : ditrace
# 1886 : nerima : nerima
# 1887 : dioperasikan : operasi
# 1888 : depresi : depresi
# 1889 : tersembuhkan : sembuh
# 1890 : mengisi : isi
# 1891 : gangguan : ganggu
# 1892 : server : server
# 1893 : menilai : nilai
# 1894 : dikantong : kantong
# 1895 : and : and
# 1896 : rezpond : rezpond
# 1897 : book : book
# 1898 : helpfull : helpfull
# 1899 : dudal : dudal
# 1900 : dudul : dudul
# 1901 : mantaaaps : mantaaaps
# 1902 : bisauang : bisauang
# 1903 : ketarik : tarik
# 1904 : membutuhkan : butuh
# 1905 : obatkapanpun : obatkapanpun
# 1906 : bimbang : bimbang
# 1907 : hamil : hamil
# 1908 : mengonsumsi : konsumsi
# 1909 : hypertiroid : hypertiroid
# 1910 : selagi : selagi
# 1911 : jarak : jarak
# 1912 : danapadahal : danapadahal
# 1913 : dokterny : dokterny
# 1914 : reaponny : reaponny
# 1915 : halodocjadwal : halodocjadwal
# 1916 : dipesan : pes
# 1917 : rasanya : rasa
# 1918 : pikir : pikir
# 1919 : membantucuma : membantucuma
# 1920 : tasi : tas
# 1921 : ahini : ahini
# 1922 : mendingan : mending
# 1923 : semahal : mahal
# 1924 : halodocuntung : halodocuntung
# 1925 : mainharga : mainharga
# 1926 : jadilah : jadi
# 1927 : pencarian : cari
# 1928 : gada : gada
# 1929 : ne : ne
# 1930 : isi : isi
# 1931 : diperbaharui : baharu
# 1932 : gerai : gerai
# 1933 : minimarket : minimarket
# 1934 : rekening : rekening
# 1935 : dipermudah : mudah
# 1936 : direkomendasikan : rekomendasi
# 1937 : teman : teman
# 1938 : interface : interface
# 1939 : userfriendly : userfriendly
# 1940 : diaplikasikan : aplikasi
# 1941 : website : website
# 1942 : logout : logout
# 1943 : buang : buang
# 1944 : memilih : pilih
# 1945 : apotikdapat : apotikdapat
# 1946 : tempuh : tempuh
# 1947 : opsi : opsi
# 1948 : mempersingkat : singkat
# 1949 : penerimanya : terima
# 1950 : keterangannya : terang
# 1951 : telponnya : telpon
# 1952 : lemot : lot
# 1953 : ikutan : ikut
# 1954 : grabgojek : grabgojek
# 1955 : genshin : genshin
# 1956 : impact : impact
# 1957 : dikirimkan : kirim
# 1958 : bantuan : bantu
# 1959 : diambil : ambil
# 1960 : selang : selang
# 1961 : kost : kost
# 1962 : pelacak : lacak
# 1963 : dibikin : bikin
# 1964 : refresh : refresh
# 1965 : berkali : kali
# 1966 : mengantar : antar
# 1967 : maximal : maximal
# 1968 : km : km
# 1969 : sampaikan : sampai
# 1970 : bertatap : tatap
# 1971 : salep : salep
# 1972 : ditemui : temu
# 1973 : berkualitas : kualitas
# 1974 : memadai : pada
# 1975 : obatmantaff : obatmantaff
# 1976 : kasiahan : kasiahan
# 1977 : boleh : boleh
# 1978 : ny : ny
# 1979 : tambahin : tambahin
# 1980 : bpd : bpd
# 1981 : cvv : cvv
# 1982 : memahami : paham
# 1983 : diantar : antar
# 1984 : bagusinteraksi : bagusinteraksi
# 1985 : cepathanya : cepathanya
# 1986 : membingungkan : bingung
# 1987 : pembayaranyamungkin : pembayaranyamungkin
# 1988 : varian : varian
# 1989 : kalangan : kalang
# 1990 : terjawab : jawab
# 1991 : lekas : lekas
# 1992 : membaik : baik
# 1993 : sangaaaaaat : sangaaaaaat
# 1994 : gue : gue
# 1995 : sts : sts
# 1996 : tlp : tlp
# 1997 : nuggu : nuggu
# 1998 : pahal : pahal
# 1999 : sangaaaaat : sangaaaaat
# 2000 : tes : tes
# 2001 : kenyataan : nyata
# 2002 : lapangan : lapang
# 2003 : ngecewain : ngecewain
# 2004 : terbilang : bilang
# 2005 : seiring : iring
# 2006 : berjalannya : jalan
# 2007 : meningkatkan : tingkat
# 2008 : stroke : stroke
# 2009 : pooll : pooll
# 2010 : lag : lag
# 2011 : rajin : rajin
# 2012 : faktanya : fakta
# 2013 : menurun : turun
# 2014 : boss : boss
# 2015 : msalah : msalah
# 2016 : permbayarnnya : permbayarnnya
# 2017 : tambah : tambah
# 2018 : saldonyasaran : saldonyasaran
# 2019 : alfamart : alfamart
# 2020 : saldosperti : saldosperti
# 2021 : sayaterimakasih : sayaterimakasih
# 2022 : malahan : malah
# 2023 : co : co
# 2024 : vouchernya : vouchernya
# 2025 : peningkatan : tingkat
# 2026 : bermanfaatdan : bermanfaatdan
# 2027 : responsemoga : responsemoga
# 2028 : kedepanya : depa
# 2029 : cepatjelas : cepatjelas
# 2030 : dung : dung
# 2031 : masing : masing
# 2032 : jelekkkkkkkkkkk : jelekkkkkkkkkkk
# 2033 : borosin : borosin
# 2034 : sadja : sadja
# 2035 : nyselllll : nyselllll
# 2036 : ganggu : ganggu
# 2037 : nonton : nonton
# 2038 : yt : yt
# 2039 : iklan : iklan
# 2040 : gbisa : gbisa
# 2041 : skip : skip
# 2042 : hemat : hemat
# 2043 : barusan : barusan
# 2044 : tahap : tahap
# 2045 : klik : klik
# 2046 : clear : clear
# 2047 : diklik : klik
# 2048 : uninst : uninst
# 2049 : instal : instal
# 2050 : intinya : inti
# 2051 : mengklik : klik
# 2052 : dikonfirmasi : konfirmasi
# 2053 : kebutuhan : butuh
# 2054 : coustumer : coustumer
# 2055 : mereka : mereka
# 2056 : awam : awam
# 2057 : nembus : nembus
# 2058 : ngantarnya : ngantarnya
# 2059 : sidoarjo : sidoarjo
# 2060 : ngantar : ngantar
# 2061 : mojokerto : mojokerto
# 2062 : yng : yng
# 2063 : mekanisme : mekanisme
# 2064 : datengnya : datengnya
# 2065 : penjual : jual
# 2066 : menanyakan : tanya
# 2067 : diproses : proses
# 2068 : perhatian : perhati
# 2069 : dihapus : hapus
# 2070 : uninstal : uninstal
# 2071 : batasi : batas
# 2072 : room : room
# 2073 : chet : chet
# 2074 : menggantung : gantung
# 2075 : tercantum : cantum
# 2076 : strip : strip
# 2077 : tablet : tablet
# 2078 : mengatur : atur
# 2079 : meskipun : meski
# 2080 : kelamaan : lama
# 2081 : dpt : dpt
# 2082 : sndri : sndri
# 2083 : ttep : ttep
# 2084 : dauh : dauh
# 2085 : puri : puri
# 2086 : kelod : kelod
# 2087 : lumintang : lumintang
# ...
# 23022 : sentra : sentra
# 23023 : syp : syp
# 23024 : pune : pune
# 23025 : punyaa : punyaa
# 23026 : teima : teima
# 23027 : sumpahhh : sumpahhh
# 23028 : wess : wess
# 23029 : jannn : jannn
# 23030 : mayan : mayan
# 23031 : apilikasinya : apilikasinya
# 23032 : kbingungan : kbingungan
# 23033 : terlama : lama
# 23034 : gutttlaaahh : gutttlaaahh
# 23035 : nila : nila
# 23036 : santia : santia
# 23037 : pf : pf
# 23038 : chelsia : chelsia
# 23039 : septianymantap : septianymantap
# 23040 : apaboleh : apaboleh
# 23041 : sepeneuh : sepeneuh
# 23042 : kukasih : kasih
# 23043 : bafu : bafu
# 23044 : meluhan : meluhan
# 23045 : ribetok : ribetok
# 23046 : memeuaskan : memeuaskan
# 23047 : sponsor : sponsor
# 23048 : kuliah : kuliah
# 23049 : pembarayan : pembarayan
# 23050 : sekalilove : sekalilove
# 23051 : kartayana : kartayana
# 23052 : cepatlugasdan : cepatlugasdan
# 23053 : bangetrama : bangetrama
# 23054 : mellati : mellati
# 23055 : zastia : zastia
# 23056 : dioerbaikipengalaman : dioerbaikipengalaman
# 23057 : mentalis : mental
# 23058 : ramahsmga : ramahsmga
# 23059 : yaablm : yaablm
# 23060 : betull : betull
# 23061 : puaaaaas : puaaaaas
# 23062 : mntabb : mntabb
# 23063 : membantutq : membantutq
# 23064 : baikmemuaskan : baikmemuaskan
# 23065 : membantuuy : membantuuy
# 23066 : dtr : dtr
# 23067 : dtrnya : dtrnya
# 23068 : jugathx : jugathx
# 23069 : pokoknyamakasih : pokoknyamakasih
# 23070 : arindatht : arindatht
# 23071 : kapsul : kapsul
# 23072 : yalupa : yalupa
# 23073 : disengajatadi : disengajatadi
# 23074 : alhmadulillah : alhmadulillah
# 23075 : sekarangsaya : sekarangsaya
# 23076 : parahketerangan : parahketerangan
# 23077 : terkonfirmasiiii : terkonfirmasiiii
# 23078 : nov : nov
# 23079 : malamsmpe : malamsmpe
# 23080 : sayaini : sayaini
# 23081 : nyawaaa : nyawaaa
# 23082 : mainindi : mainindi
# 23083 : gunadi : gunadi
# 23084 : bergunaaaapublik : bergunaaaapublik
# 23085 : baiknyaa : baiknyaa
# 23086 : lahmudah : lahmudah
# 23087 : bgtfree : bgtfree
# 23088 : membutuhkannya : butuh
# 23089 : mencelaskan : celas
# 23090 : sukaakk : sukaakk
# 23091 : dokternyabaik : dokternyabaik
# 23092 : allhmdulilah : allhmdulilah
# 23093 : urray : urray
# 23094 : tengku : tengku
# 23095 : draliqa : draliqa
# 23096 : septiani : septiani
# 23097 : mmrsukses : mmrsukses
# 23098 : belumtahu : belumtahu
# 23099 : membantutrimksh : membantutrimksh
# 23100 : danmurah : danmurah
# 23101 : blsx : blsx
# 23102 : bagusmudahan : bagusmudahan
# 23103 : puuuasss : puuuasss
# 23104 : inidkter : inidkter
# 23105 : sekalipdhal : sekalipdhal
# 23106 : sudahbmembantu : sudahbmembantu
# 23107 : pusar : pusar
# 23108 : komunikatifsy : komunikatifsy
# 23109 : yrima : yrima
# 23110 : sianghasil : sianghasil
# 23111 : obatnyatk : obatnyatk
# 23112 : dahcpet : dahcpet
# 23113 : tngh : tngh
# 23114 : tnyain : tnyain
# 23115 : staybye : staybye
# 23116 : ribetbetulin : ribetbetulin
# 23117 : eltari : eltari
# 23118 : manjurlangsung : manjurlangsung
# 23119 : sembuhterimakasih : sembuhterimakasih
# 23120 : wiliamboot : wiliamboot
# 23121 : dintar : dintar
# 23122 : kecebong : kecebong
# 23123 : eeeeeh : eeeeeh
# 23124 : cahat : cahat
# 23125 : manalagi : manalagi
# 23126 : pembayaranpun : bayar
# 23127 : panikanmakasih : panikanmakasih
# 23128 : alhmdllhsangat : alhmdllhsangat
# 23129 : petanya : peta
# 23130 : kusuka : suka
# 23131 : dimengrti : dimengrti
# 23132 : yha : yha
# 23133 : mmr : mmr
# 23134 : kelender : lender
# 23135 : mantaapppp : mantaapppp
# 23136 : taynya : taynya
# 23137 : membsntu : membsntu
# 23138 : kbtulan : kbtulan
# 23139 : surya : surya
# 23140 : spkkdiberkati : spkkdiberkati
# 23141 : yangi : yang
# 23142 : uta : uta
# 23143 : alahamdulillahsangat : alahamdulillahsangat
# 23144 : layananyathanks : layananyathanks
# 23145 : tidakmenemukan : tidakmenemukan
# 23146 : nyatksh : nyatksh
# 23147 : membls : membls
# 23148 : kebaikn : kebaikn
# 23149 : dokteramiin : dokteramiin
# 23150 : lolaaaa : lolaaaa
# 23151 : bangetz : bangetz
# 23152 : apliksnya : apliksnya
# 23153 : membwrikan : membwrikan
# 23154 : okkerenakurat : okkerenakurat
# 23155 : drjuan : drjuan
# 23156 : halodocpake : halodocpake
# 23157 : dicanangkan : canang
# 23158 : fr : fr
# 23159 : topi : topi
# 23160 : mmbtu : mmbtu
# 23161 : dokterpenjelasannya : dokterpenjelasannya
# 23162 : rin : rin
# 23163 : dokteraamiin : dokteraamiin
# 23164 : siih : siih
# 23165 : kerendokterx : kerendokterx
# 23166 : godd : godd
# 23167 : puaspuas : puaspuas
# 23168 : dahbagus : dahbagus
# 23169 : zerviani : zerviani
# 23170 : oktavinda : oktavinda
# 23171 : migrants : migrants
# 23172 : wkwkwkwk : wkwkwkwk
# 23173 : mantappokoknya : mantappokoknya
# 23174 : manfaan : manfaan
# 23175 : drlisa : drlisa
# 23176 : padamu : pada
# 23177 : satusekedar : satusekedar
# 23178 : melepas : lepas
# 23179 : bermanfaa : bermanfaa
# 23180 : goks : goks
# 23181 : mantebbb : mantebbb
# 23182 : pengalama : pengalama
# 23183 : lyanannya : lyanannya
# 23184 : blasnya : blasnya
# 23185 : nth : nth
# 23186 : jringan : jringan
# 23187 : ggak : ggak
# 23188 : mmng : mmng
# 23189 : baikny : baikny
# 23190 : direspin : direspin
# 23191 : hujanan : hujan
# 23192 : playanannnya : playanannnya
# 23193 : bangetefektif : bangetefektif
# 23194 : ngedonlodmau : ngedonlodmau
# 23195 : kulitsemoga : kulitsemoga
# 23196 : mmuaskn : mmuaskn
# 23197 : doktermski : doktermski
# 23198 : langaungsmga : langaungsmga
# 23199 : beeikan : beeikan
# 23200 : biasaservicenya : biasaservicenya
# 23201 : vaksinnya : vaksin
# 23202 : kehmilan : kehmilan
# 23203 : detile : detile
# 23204 : mantpcepat : mantpcepat
# 23205 : perhatiannn : perhatiannn
# 23206 : duluntr : duluntr
# 23207 : post : post
# 23208 : axa : axa
# 23209 : menberi : menberi
# 23210 : huhuhulama : huhuhulama
# 23211 : nginstalnya : nginstalnya
# 23212 : monica : monica
# 23213 : gabe : gabe
# 23214 : hakodok : hakodok
# 23215 : memudakan : muda
# 23216 : memuaskaan : memuaskaan
# 23217 : brmangpaat : brmangpaat
# 23218 : masyhud : masyhud
# 23219 : downloadtemanteman : downloadtemanteman
# 23220 : tobsemoga : tobsemoga
# 23221 : santuyyy : santuyyy
# 23222 : sekalitanks : sekalitanks
# 23223 : hslo : hslo
# 23224 : pencita : cita
# 23225 : andemmi : andemmi
# 23226 : menyiatkan : siat
# 23227 : menjawabi : jawab
# 23228 : kerreeen : kerreeen
# 23229 : temanhidup : temanhidup
# 23230 : skki : skki
# 23231 : mantabbbbb : mantabbbbb
# 23232 : aaagara : aaagara
# 23233 : najwasmoga : najwasmoga
# 23234 : sihb : sihb
# 23235 : bgetdan : bgetdan
# 23236 : mashaallah : mashaallah
# 23237 : memuwaskan : memuwaskan
# 23238 : mengispirasi : mengispirasi
# 23239 : pertamasamgat : pertamasamgat
# 23240 : baguskerenmemuaskan : baguskerenmemuaskan
# 23241 : tspi : tspi
# 23242 : okbangatterimakasi : okbangatterimakasi
# 23243 : typus : typus
# 23244 : infus : infus
# 23245 : nmnya : nmnya
# 23246 : dahlah : dah
# 23247 : oghey : oghey
# 23248 : bay : bay
# 23249 : apilasi : apilasi
# 23250 : senwng : senwng
# 23251 : doktergratis : doktergratis
# 23252 : mantabmembantu : mantabmembantu
# 23253 : mantp : mantp
# 23254 : wau : wau
# 23255 : menanggulangi : tanggulang
# 23256 : hertha : hertha
# 23257 : cristabelle : cristabelle
# 23258 : hambalie : hambalie
# 23259 : octaviany : octaviany
# 23260 : gultom : gultom
# 23261 : selnjut : selnjut
# 23262 : pokoknyapelayanan : pokoknyapelayanan
# 23263 : respomnya : respomnya
# 23264 : docapakah : docapakah
# 23265 : divaccine : divaccine
# 23266 : sinovacboleh : sinovacboleh
# 23267 : mamberi : mamberi
# 23268 : sejali : jali
# 23269 : manthaaaap : manthaaaap
# 23270 : ayodoong : ayodoong
# 23271 : indramayu : indramayu
# 23272 : siiipn : siiipn
# 23273 : diperinci : perinci
# 23274 : consultasinya : consultasinya
# 23275 : cakupannya : cakup
# 23276 : cepetpokokx : cepetpokokx
# 23277 : kereensangat : kereensangat
# 23278 : gabungsemoga : gabungsemoga
# 23279 : permainan : main
# 23280 : responden : responden
# 23281 : okkeeyy : okkeeyy
# 23282 : halli : halli
# 23283 : dengang : dengang
# 23284 : jaeaban : jaeaban
# 23285 : nyusul : nyusul
# 23286 : sklimksih : sklimksih
# 23287 : banyakdok : banyakdok
# 23288 : dbrkan : dbrkan
# 23289 : nelpin : nelpin
# 23290 : astaghfirullah : astaghfirullah
# 23291 : chatok : chatok
# 23292 : apotikdikirim : apotikdikirim
# 23293 : rumahterimakasih : rumahterimakasih
# 23294 : iformasi : iformasi
# 23295 : meringkankan : meringkankan
# 23296 : dulublm : dulublm
# 23297 : menelfon : menelfon
# 23298 : tfn : tfn
# 23299 : kshaplikasi : kshaplikasi
# 23300 : bangeth : bangeth
# 23301 : membangtu : membangtu
# 23302 : pandeleke : pandeleke
# 23303 : dokterxsmga : dokterxsmga
# 23304 : soni : soni
# 23305 : wicaksono : wicaksono
# 23306 : bah : bah
# 23307 : basudewa : basudewa
# 23308 : sejatibaik : sejatibaik
# 23309 : diberikannya : beri
# 23310 : silfia : silfia
# 23311 : mandasari : mandasari
# 23312 : dv : dv
# 23313 : parahfast : parahfast
# 23314 : kecewaaaaaaa : kecewaaaaaaa
# 23315 : membatuterimakasih : membatuterimakasih
# 23316 : dokternyatrimakadih : dokternyatrimakadih
# 23317 : jessnolimit : jessnolimit
# 23318 : andrianor : andrianor
# 23319 : rachman : rachman
# 23320 : pencerhanya : pencerhanya
# 23321 : okobat : okobat
# 23322 : sampeterimakasih : sampeterimakasih
# 23323 : berkwalitas : berkwalitas
# 23324 : informatifmudah : informatifmudah
# 23325 : pelayanann : pelayanann
# 23326 : selalau : lalau
# 23327 : trimas : trimas
# 23328 : smbg : smbg
# 23329 : subskrep : subskrep
# 23330 : atta : atta
# 23331 : gledek : gledek
# 23332 : ameniya : ameniya
# 23333 : bunting : bunting
# 23334 : bagad : bagad
# 23335 : terrmksh : terrmksh
# 23336 : siipwalau : siipwalau
# 23337 : okmksh : okmksh
# 23338 : dikonsulkan : konsul
# 23339 : sharaf : sharaf
# 23340 : cepathalodoc : cepathalodoc
# 23341 : ntu : ntu
# 23342 : mantaaapsangat : mantaaapsangat
# 23343 : respontrimaksih : respontrimaksih
# 23344 : sekalibagusss : sekalibagusss
# 23345 : donwloadnya : donwloadnya
# 23346 : rinciiii : rinciiii
# 23347 : kasihcepet : kasihcepet
# 23348 : setigini : setigini
# 23349 : gimama : gimama
# 23350 : prince : prince
# 23351 : gusti : gusti
# 23352 : bagussmembantu : bagussmembantu
# 23353 : trmkshkali : trmkshkali
# 23354 : pertamackp : pertamackp
# 23355 : manyusss : manyusss
# 23356 : sekalimantaaaaaappp : sekalimantaaaaaappp
# 23357 : mpermudah : mpermudah
# 23358 : cakepsangat : cakepsangat
# 23359 : mbembantu : mbembantu
# 23360 : mantapmemuaskan : mantapmemuaskan
# 23361 : cbk : cbk
# 23362 : udg : udg
# 23363 : fu : fu
# 23364 : furies : furies
# 23365 : alhamdulliah : alhamdulliah
# 23366 : bgtmemudahkan : bgtmemudahkan
# 23367 : pasienlanjukan : pasienlanjukan
# 23368 : padattks : padattks
# 23369 : tersumbat : sumbat
# 23370 : konsultasisemogaa : konsultasisemogaa
# 23371 : lbj : lbj
# 23372 : penjelasany : penjelasany
# 23373 : mksii : mksii
# 23374 : sejeki : sejeki
# 23375 : surfe : surfe
# 23376 : indormatif : indormatif
# 23377 : apotekk : apotekk
# 23378 : bhsanya : bhsanya
# 23379 : bergunalah : guna
# 23380 : apliksasinyaa : apliksasinyaa
# 23381 : yaadokter : yaadokter
# 23382 : mantulmantap : mantulmantap
# 23383 : sukangebantu : sukangebantu
# 23384 : dihentikan : henti
# 23385 : edan : edan
# 23386 : temaaaaan : temaaaaan
# 23387 : sehta : sehta
# 23388 : drnnya : drnnya
# 23389 : membbatu : membbatu
# 23390 : ramaaaaahhhh : ramaaaaahhhh
# 23391 : adrianus : adrianus
# 23392 : terpercayadan : terpercayadan
# 23393 : memudahkantanpa : memudahkantanpa
# 23394 : mekarsari : mekarsari
# 23395 : okmembantu : okmembantu
# 23396 : factual : factual
# 23397 : terimakakaih : terimakakaih
# 23398 : masukn : masukn
# 23399 : mantapresponsif : mantapresponsif
# 23400 : ratu : ratu
# 23401 : metty : metty
# 23402 : menuaskan : tuas
# 23403 : gooooooooooooddddddddddd : gooooooooooooddddddddddd
# 23404 : dullu : dullu
# 23405 : ramaaaaaah : ramaaaaaah
# 23406 : war : war
# 23407 : biyasa : biyasa
# 23408 : brahm : brahm
# 23409 : omaygat : omaygat
# 23410 : dipkai : dipkai
# 23411 : dikurngi : dikurngi
# 23412 : bntng : bntng
# 23413 : comfirmasi : comfirmasi
# 23414 : sukakkkkk : sukakkkkk
# 23415 : farissa : farissa
# 23416 : rnak : rnak
# 23417 : sanat : sanat
# 23418 : sagant : sagant
# 23419 : puasssudh : puasssudh
# 23420 : melegenda : legenda
# 23421 : kumpulan : kumpul
# 23422 : mantulrecommended : mantulrecommended
# 23423 : memusakan : pusa
# 23424 : baiiiikkk : baiiiikkk
# 23425 : responenya : responenya
# 23426 : miskinmasa : miskinmasa
# 23427 : burnmasyarakat : burnmasyarakat
# 23428 : tertolongtolong : tertolongtolong
# 23429 : burn : burn
# 23430 : mudahmurahcepat : mudahmurahcepat
# 23431 : membantub : membantub
# 23432 : konsultasibya : konsultasibya
# 23433 : krang : krang
# 23434 : burugtu : burugtu
# 23435 : uuucudan : uuucudan
# 23436 : ucucccxx : ucucccxx
# 23437 : sinj : sinj
# 23438 : anj : anj
# 23439 : donor : donor
# 23440 : segar : segar
# 23441 : tololl : tololl
# 23442 : gblkk : gblkk
# 23443 : anosmia : anosmia
# 23444 : kereeeennnn : kereeeennnn
# 23445 : sangatembantu : sangatembantu
# 23446 : perluantri : perluantri
# 23447 : dockamu : dockamu
# 23448 : rekomendedmdhan : rekomendedmdhan
# 23449 : segara : segara
# 23450 : robbalalamin : robbalalamin
# 23451 : okbisa : okbisa
# 23452 : ngurangi : ngurangi
# 23453 : cemasthank : cemasthank
# 23454 : disayangaplikasi : disayangaplikasi
# 23455 : mantabh : mantabh
# 23456 : cocokuntuk : cocokuntuk
# 23457 : puss : puss
# 23458 : boskulangsung : boskulangsung
# 23459 : mogah : mogah
# 23460 : berikn : berikn
# 23461 : antusiascare : antusiascare
# 23462 : uwuww : uwuww
# 23463 : sipz : sipz
# 23464 : amanlancar : amanlancar
# 23465 : sangatbmembantu : sangatbmembantu
# 23466 : sukasaya : sukasaya
# 23467 : konyol : konyol
# 23468 : tksuntuk : tksuntuk
# 23469 : silvania : silvania
# 23470 : maisya : maisya
# 23471 : smogga : smogga
# 23472 : drdina : drdina
# 23473 : cantikramahrespon : cantikramahrespon
# 23474 : ajjg : ajjg
# 23475 : trmaksih : trmaksih
# 23476 : infony : infony
# 23477 : dralhan : dralhan
# 23478 : baagusss : baagusss
# 23479 : kereeeeennnnnnterima : kereeeeennnnnnterima
# 23480 : installl : installl
# 23481 : drastis : drastis
# 23482 : baikbermanfaat : baikbermanfaat
# 23483 : malamhari : malamhari
# 23484 : konsulgood : konsulgood
# 23485 : bagusdapat : bagusdapat
# 23486 : situaasi : situaasi
# 23487 : anindya : anindya
# 23488 : septiawati : septiawati
# 23489 : mangtap : mangtap
# 23490 : haloeoc : haloeoc
# 23491 : bangettttmeski : bangettttmeski
# 23492 : ssngatt : ssngatt
# 23493 : aris : aris
# 23494 : cahyono : cahyono
# 23495 : ditanggapai : ditanggapai
# 23496 : sbuh : sbuh
# 23497 : montok : montok
# 23498 : bahenol : bahenol
# 23499 : trimksi : trimksi
# 23500 : santuntimaksih : santuntimaksih
# 23501 : insayaallah : insayaallah
# 23502 : beeet : beeet
# 23503 : ngangu : ngangu
# 23504 : jwbanny : jwbanny
# 23505 : kerimah : kerimah
# 23506 : masyaallahh : masyaallahh
# 23507 : januar : januar
# 23508 : respondokter : respondokter
# 23509 : appx : appx
# 23510 : suangat : suangat
# 23511 : pelayanab : pelayanab
# 23512 : rohmati : rohmat
# 23513 : wahidah : wahidah
# 23514 : kcl : kcl
# 23515 : alhadulilah : alhadulilah
# 23516 : mnganalisa : mnganalisa
# 23517 : agakk : agakk
# 23518 : konsuldengan : konsuldengan
# 23519 : notivikasi : notivikasi
# 23520 : lagusng : lagusng
# 23521 : mantaaaaab : mantaaaaab
# 23522 : dehc : dehc
# 23523 : rass : rass
# 23524 : jeb : jeb
# 23525 : patenlah : paten
# 23526 : alhamdl : alhamdl
# 23527 : olivia : olivia
# 23528 : andalkanmksh : andalkanmksh
# 23529 : perbincangannya : bincang
# 23530 : tiktok : tiktok
# 23531 : seklaitrimakasih : seklaitrimakasih
# 23532 : jbw : jbw
# 23533 : hayoo : hayoo
# 23534 : memvntu : memvntu
# 23535 : baro : baro
# 23536 : dabestlahh : dabestlahh
# 23537 : tanding : tanding
# 23538 : loviu : loviu
# 23539 : nemenin : nemenin
# 23540 : nikigbu : nikigbu
# 23541 : drhafidh : drhafidh
# 23542 : bnanget : bnanget
# 23543 : kla : kla
# 23544 : mendep : mendep
# 23545 : responshipdokternya : responshipdokternya
# 23546 : memudahkannuntuk : memudahkannuntuk
# 23547 : maasyaallah : maasyaallah
# 23548 : edrianus : edrianus
# 23549 : terbaikkkk : terbaikkkk
# 23550 : ngatrii : ngatrii
# 23551 : chaatt : chaatt
# 23552 : rifqah : rifqah
# 23553 : syarief : syarief
# 23554 : hannifan : hannifan
# 23555 : halocod : halocod
# 23556 : pelayanantks : pelayanantks
# 23557 : enakk : enakk
# 23558 : bermanfaaaaaaat : bermanfaaaaaaat
# 23559 : memberiii : memberiii
# 23560 : solusiii : solusiii
# 23561 : mlam : mlam
# 23562 : kbtln : kbtln
# 23563 : rekomnded : rekomnded
# 23564 : jawban : jawban
# 23565 : konshltasi : konshltasi
# 23566 : masakini : masakini
# 23567 : resepnyaa : resepnyaa
# 23568 : meresponse : meresponse
# 23569 : imbost : imbost
# 23570 : doksgt : doksgt
# 23571 : keressn : keressn
# 23572 : buagusss : buagusss
# 23573 : biasamembantu : biasamembantu
# 23574 : untukmudahkan : untukmudahkan
# 23575 : terbalik : balik
# 23576 : sblim : sblim

# %%
#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data['stemm'] = data['tokenize'].apply(lambda x:' '.join(get_stemmed_term(x)))
data.head(20)

# %%
data.to_csv("ulasan siloam hospital.csv",index=False, encoding='utf-8')
